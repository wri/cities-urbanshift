# %%
import os, json
import pandas as pd
import boto3
import geopandas as gpd

from math import floor
from pystac_client import Client
import planetary_computer as pc
import numpy as np
import rasterio
import requests, pyproj
from pyproj.aoi import AreaOfInterest
from pyproj.database import query_utm_crs_info
from rasterio.merge import merge as rmerge
import rasterio.mask
from rasterio.features import shapes
from shapely.geometry import Polygon, MultiPolygon, box
from shapely.ops import transform, unary_union
import networkx as nx

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
CONNECTIVITY_DISTANCE = 100    # Max distance two patches can be apart and be considered connected (meter)
MIN_PATCHSIZE = 1000    # Min patch size to be included in analysis (sq meter)

# %%
# get list of urbanshift cities
boundary_georef = pd.read_csv('https://cities-urbanshift.s3.eu-west-3.amazonaws.com/data/boundaries/v_0/boundary_georef.csv')

# %%
boundary_georef
# Out:
#              geo_name   level aoi_boundary_name units_boundary_name  \
# 0         ARG-Mendoza  region         ADM3union                ADM3
# 1   ARG-Mar_del_Plata    city              ADM3                ADM4
# 2   ARG-Mar_del_Plata  region              ADM2                 NaN
# 3         ARG-Ushuaia    city              ADM4                ADM5
# 4         ARG-Ushuaia  region              ADM3                 NaN
# 5           ARG-Salta  region         ADM2union                ADM3
# 6    ARG-Buenos_Aires  region         ADM2union                ADM2
# 7        BRA-Teresina    city         ADM4union                ADM4
# 8        BRA-Teresina  region         ADM2union                ADM2
# 9   BRA-Florianopolis    city         ADM4union                ADM4
# 10  BRA-Florianopolis  region         ADM2union                ADM2
# 11          BRA-Belem    city         ADM4union                ADM4
# 12          BRA-Belem  region         ADM2union                ADM2
# 13       CRI-San_Jose  region         ADM2union                ADM2
# 14         RWA-Kigali    city         ADM4union                ADM4
# 15       SLE-Freetown    city     ADM4cityunion            ADM4city
# 16       SLE-Freetown  region   ADM4regionunion          ADM4region
# 17      MAR-Marrakech     NaN              ADM2                ADM5
# 18        IND-Chennai  region         ADM4union                ADM4
# 19        IND-Chennai    city         ADM6union                ADM6
# 20           IND-Pune  region         ADM4union                ADM4
# 21          IND-Surat  region         ADM4union                ADM4
# 22        CHN-Chengdu     NaN         ADM3union                ADM3
# 23      CHN-Chongqing     NaN              ADM1                ADM3
# 24         CHN-Ningbo     NaN         ADM3union                ADM3
# 25        IDN-Jakarta     NaN         ADM4union                ADM4
# 26         IDN-Bitung     NaN              ADM2                ADM3
# 27       IDN-Semarang     NaN              ADM1                ADM4
# 28     IDN-Balikpapan     NaN         ADM4union                ADM4
# 29      IDN-Palembang     NaN              ADM2                ADM3
#
#                city_name  country_name country_code continent
# 0                Mendoza     Argentina          ARG   America
# 1     Mar del Plata city     Argentina          ARG   America
# 2   Mar del Plata region     Argentina          ARG   America
# 3           Ushuaia city     Argentina          ARG   America
# 4         Ushuaia region     Argentina          ARG   America
# 5                  Salta     Argentina          ARG   America
# 6           Buenos Aires     Argentina          ARG   America
# 7          Teresina city        Brazil          BRA   America
# 8        Teresina region        Brazil          BRA   America
# 9          Florianopolis        Brazil          BRA   America
# 10         Florianopolis        Brazil          BRA   America
# 11            Belem city        Brazil          BRA   America
# 12          Belem region        Brazil          BRA   America
# 13              San Jose    Costa Rica          CRI   America
# 14                Kigali        Rwanda          RWA    Africa
# 15         Freetown city  Sierra Leone          SLE    Africa
# 16       Freetown region  Sierra Leone          SLE    Africa
# 17             Marrakech       Morocco          MAR    Africa
# 18        Chennai region         India          IND      Asia
# 19          Chennai city         India          IND      Asia
# 20                 Pune          India          IND      Asia
# 21                 Surat         India          IND      Asia
# 22               Chengdu         China          CHN      Asia
# 23             Chongqing         China          CHN      Asia
# 24                Ningbo         China          CHN      Asia
# 25               Jakarta     Indonesia          IDN      Asia
# 26                Bitung     Indonesia          IDN      Asia
# 27              Semarang     Indonesia          IDN      Asia
# 28            Balikpapan     Indonesia          IDN      Asia
# 29             Palembang     Indonesia          IDN      Asia

# %%
# Convert district-boundary geojsons to Shapely polygons

def geojson_to_polygons(g):
    result = []
    for feature in g['features']:
        name = feature['properties']['geo_name']
        if type(feature['geometry']['coordinates'][0][0][0]) == list:
            coordpairs = [(float(i[0]), float(i[1])) for i in feature['geometry']['coordinates'][0][0]]
        else:
            coordpairs = [(float(i[0]), float(i[1])) for i in feature['geometry']['coordinates'][0]]
        result.append((name, Polygon(coordpairs)))
    return result

#district_polys = geojson_to_polygons(Districts_json)

# %%
# This function clips and masks raster
# Adapted from https://gis.stackexchange.com/a/387772

def mask_raster_with_geometry(raster, transform, shapes, **kwargs):
    """Wrapper for rasterio.mask.mask to allow for in-memory processing.

    Docs: https://rasterio.readthedocs.io/en/latest/api/rasterio.mask.html

    Args:
        raster (numpy.ndarray): raster to be masked with dim: [H, W]
        transform (affine.Affine): the transform of the raster
        shapes, **kwargs: passed to rasterio.mask.mask

    Returns:
        masked: numpy.ndarray or numpy.ma.MaskedArray with dim: [H, W], and new affine transform
    """
    with rasterio.io.MemoryFile() as memfile:
        with memfile.open(
            driver='GTiff',
            height=raster.shape[0],
            width=raster.shape[1],
            count=1,
            dtype=raster.dtype,
            transform=transform,
        ) as dataset:
            dataset.write(raster, 1)
        with memfile.open() as dataset:
            output, new_transform = rasterio.mask.mask(dataset, shapes, **kwargs)
    return output.squeeze(0), new_transform

# %%
# Reclassify from ESA WorldCover classes to habitat/nonhabitat

def classify_habitat(r):  # Note: order is important
    r[r == 60] = 1    # sparse veg
    r[r >= 90] = 1    # herbaceous wetland, mangrove, lichen & moss
    r[r == 80] = 0    # permanent open water
    r[r == 70] = 0    # snow/ice
    r[r == 40] = 0    # cropland
    r[r == 50] = 0    # built up
    r[r >= 10] = 1    # tree, shrub, grassland
    r[r == 0] = 0

    return r

# %%
def within_distance(rownum, gdf, sidx):
    if rownum % 1000 == 0:
        print('     {0} / {1}'.format(rownum, gdf.count().geometry))
    z = list(sidx.intersection(gdf.iloc[rownum].geometry.buffer(CONNECTIVITY_DISTANCE).bounds))
    distances = gdf.iloc[z].distance(gdf.iloc[rownum].geometry)
    return [i for i in z if distances[i] <= CONNECTIVITY_DISTANCE if i != rownum]

# %%
def do_one_geom(row):
    print(row['geo_id'], row['geo_name'])
    geom = row[0]
    if type(geom) == MultiPolygon:
        district_poly = MultiPolygon(row[0])
    else:
        district_poly = MultiPolygon([row[0]])
    bounds = district_poly.bounds
    centroid_lon = district_poly.centroid.xy[0][0]
    centroid_lat = district_poly.centroid.xy[1][0]
    target_epsg = (32600 + [0, 100][int(centroid_lat < 0)]) + floor((180 + centroid_lon) / 6) + 1
    # EPSG is 32600 (or 32700 if lat is neg) + longitude zone. Each zone is six degrees, and first zone is 1.
    # Transform from EPSG:4326 to target EPSG
    project = pyproj.Transformer.from_crs(
        pyproj.CRS.from_epsg(4326), # source coordinate system
        pyproj.CRS.from_epsg(target_epsg), # destination coordinate system
        always_xy=True
    )
    # Get ESA WorldCover raster tiles covering AOI
    catalog = Client.open("https://planetarycomputer.microsoft.com/api/stac/v1")
    search = catalog.search(
        collections=["esa-worldcover"],
        bbox=bounds,
    )
    items = list(search.get_items())
    rasters_to_mosaic = []
    signed_hrefs = [pc.sign(i.assets["map"].href) for i in items]
    for href in signed_hrefs:
        raster = rasterio.open(href)
        rasters_to_mosaic.append(raster)

    # Stitch rasters together
    mosaic, mosaic_transform = rmerge(rasters_to_mosaic)
    # Clip raster to district boundary
    clipped_raster, clip_transform = mask_raster_with_geometry(mosaic[0], mosaic_transform, district_poly, crop=True)
    # Classify clipped raster as habitat/nonhabitat
    hab_raster = classify_habitat(clipped_raster)
    # Vectorize and collect only the habitat patches (as opposed to nonhabitat)
    with rasterio.Env():
        image = hab_raster
        results = (
        {'properties': {'raster_val': v}, 'geometry': s}
        for (s, v) 
        in shapes(image, transform=clip_transform) if v == 1)
    shapelist = list(results)
    shapelist = shapelist[:-1]
    all_patches = [  # project to UTM so that spatial unit is meter
        transform(project.transform, Polygon(shapelist[i]['geometry']['coordinates'][0])) for i in range(len(shapelist))
    ]
    patches = [
        i for i in [j.simplify(10, preserve_topology=False) for j in all_patches] if i.area >= MIN_PATCHSIZE # Remove very small patches from consideration
    #    i for i in all_patches if i.area >= MIN_PATCHSIZE # Remove very small patches from consideration
    ]
    patchgeoms = gpd.GeoDataFrame(geometry=patches, crs='EPSG:{}'.format(target_epsg), index=range(len(patches)))
    patchgeoms_sindex = patchgeoms.sindex


    connected = {
        i: within_distance(i, patchgeoms, patchgeoms_sindex) for i in range(len(patches))
    }
    # Find clusters from connected pairs
    edges = []
    for k in connected:
        for i in connected[k]:
            edges.append((k, i))
    G = nx.Graph()
    G.add_nodes_from(range(len(patches)))
    G.add_edges_from(edges)
    clusters = nx.connected_components(G)
    # Calculate indicator
    total_area = sum([i.area for i in patches])
    cluster_areas = []
    for i in clusters:
        cluster_areas.append(sum([patches[j].area for j in i]))
    if total_area > 0:
        return sum([i**2 for i in cluster_areas]) / (total_area**2)
    else:
        return 0

# %%
# %%time
results = []
for i in range(len(boundary_georef)): 
    for boundary_name in ['aoi_boundary_name', 'units_boundary_name']:
        if type(boundary_georef.loc[i, boundary_name]) != float: # sometimes boundary_id is nan
            boundary_id = boundary_georef.loc[i, 'geo_name'] + '-' + boundary_georef.loc[i, boundary_name]
            # read boundaries
            boundary_path = 'https://cities-urbanshift.s3.eu-west-3.amazonaws.com/data/boundaries/v_0/boundary-'+boundary_id +'.geojson'
            boundary_geo = requests.get(boundary_path).json()
            gdf = gpd.GeoDataFrame.from_features(boundary_geo)
            gdf['BIO-2'] = gdf.apply(do_one_geom, axis=1)
            results.append(gdf[['geo_id', 'geo_name', 'BIO-2']].copy())
            output = pd.concat(results, axis=0)
            output.to_csv('BIO-2.csv')
# Out:
# CHN-Chengdu_ADM-3-union_1 CHN-Chengdu
#      0 / 310193
#      1000 / 310193
#      2000 / 310193
#      3000 / 310193
#      4000 / 310193
#      5000 / 310193
#      6000 / 310193
#      7000 / 310193
#      8000 / 310193
#      9000 / 310193
#      10000 / 310193
#      11000 / 310193
#      12000 / 310193
#      13000 / 310193
#      14000 / 310193
#      15000 / 310193
#      16000 / 310193
#      17000 / 310193
#      18000 / 310193
#      19000 / 310193
#      20000 / 310193
#      21000 / 310193
#      22000 / 310193
#      23000 / 310193
#      24000 / 310193
#      25000 / 310193
#      26000 / 310193
#      27000 / 310193
#      28000 / 310193
#      29000 / 310193
#      30000 / 310193
#      31000 / 310193
#      32000 / 310193
#      33000 / 310193
#      34000 / 310193
#      35000 / 310193
#      36000 / 310193
#      37000 / 310193
#      38000 / 310193
#      39000 / 310193
#      40000 / 310193
#      41000 / 310193
#      42000 / 310193
#      43000 / 310193
#      44000 / 310193
#      45000 / 310193
#      46000 / 310193
#      47000 / 310193
#      48000 / 310193
#      49000 / 310193
#      50000 / 310193
#      51000 / 310193
#      52000 / 310193
#      53000 / 310193
#      54000 / 310193
#      55000 / 310193
#      56000 / 310193
#      57000 / 310193
#      58000 / 310193
#      59000 / 310193
#      60000 / 310193
#      61000 / 310193
#      62000 / 310193
#      63000 / 310193
#      64000 / 310193
#      65000 / 310193
#      66000 / 310193
#      67000 / 310193
#      68000 / 310193
#      69000 / 310193
#      70000 / 310193
#      71000 / 310193
#      72000 / 310193
#      73000 / 310193
#      74000 / 310193
#      75000 / 310193
#      76000 / 310193
#      77000 / 310193
#      78000 / 310193
#      79000 / 310193
#      80000 / 310193
#      81000 / 310193
#      82000 / 310193
#      83000 / 310193
#      84000 / 310193
#      85000 / 310193
#      86000 / 310193
#      87000 / 310193
#      88000 / 310193
#      89000 / 310193
#      90000 / 310193
#      91000 / 310193
#      92000 / 310193
#      93000 / 310193
#      94000 / 310193
#      95000 / 310193
#      96000 / 310193
#      97000 / 310193
#      98000 / 310193
#      99000 / 310193
#      100000 / 310193
#      101000 / 310193
#      102000 / 310193
#      103000 / 310193
#      104000 / 310193
#      105000 / 310193
#      106000 / 310193
#      107000 / 310193
#      108000 / 310193
#      109000 / 310193
#      110000 / 310193
#      111000 / 310193
#      112000 / 310193
#      113000 / 310193
#      114000 / 310193
#      115000 / 310193
#      116000 / 310193
#      117000 / 310193
#      118000 / 310193
#      119000 / 310193
#      120000 / 310193
#      121000 / 310193
#      122000 / 310193
#      123000 / 310193
#      124000 / 310193
#      125000 / 310193
#      126000 / 310193
#      127000 / 310193
#      128000 / 310193
#      129000 / 310193
#      130000 / 310193
#      131000 / 310193
#      132000 / 310193
#      133000 / 310193
#      134000 / 310193
#      135000 / 310193
#      136000 / 310193
#      137000 / 310193
#      138000 / 310193
#      139000 / 310193
#      140000 / 310193
#      141000 / 310193
#      142000 / 310193
#      143000 / 310193
#      144000 / 310193
#      145000 / 310193
#      146000 / 310193
#      147000 / 310193
#      148000 / 310193
#      149000 / 310193
#      150000 / 310193
#      151000 / 310193
#      152000 / 310193
#      153000 / 310193
#      154000 / 310193
#      155000 / 310193
#      156000 / 310193
#      157000 / 310193
#      158000 / 310193
#      159000 / 310193
#      160000 / 310193
#      161000 / 310193
#      162000 / 310193
#      163000 / 310193
#      164000 / 310193
#      165000 / 310193
#      166000 / 310193
#      167000 / 310193
#      168000 / 310193
#      169000 / 310193
#      170000 / 310193
#      171000 / 310193
#      172000 / 310193
#      173000 / 310193
#      174000 / 310193
#      175000 / 310193
#      176000 / 310193
#      177000 / 310193
#      178000 / 310193
#      179000 / 310193
#      180000 / 310193
#      181000 / 310193
#      182000 / 310193
#      183000 / 310193
#      184000 / 310193
#      185000 / 310193
#      186000 / 310193
#      187000 / 310193
#      188000 / 310193
#      189000 / 310193
#      190000 / 310193
#      191000 / 310193
#      192000 / 310193
#      193000 / 310193
#      194000 / 310193
#      195000 / 310193
#      196000 / 310193
#      197000 / 310193
#      198000 / 310193
#      199000 / 310193
#      200000 / 310193
#      201000 / 310193
#      202000 / 310193
#      203000 / 310193
#      204000 / 310193
#      205000 / 310193
#      206000 / 310193
#      207000 / 310193
#      208000 / 310193
#      209000 / 310193
#      210000 / 310193
#      211000 / 310193
#      212000 / 310193
#      213000 / 310193
#      214000 / 310193
#      215000 / 310193
#      216000 / 310193
#      217000 / 310193
#      218000 / 310193
#      219000 / 310193
#      220000 / 310193
#      221000 / 310193
#      222000 / 310193
#      223000 / 310193
#      224000 / 310193
#      225000 / 310193
#      226000 / 310193
#      227000 / 310193
#      228000 / 310193
#      229000 / 310193
#      230000 / 310193
#      231000 / 310193
#      232000 / 310193
#      233000 / 310193
#      234000 / 310193
#      235000 / 310193
#      236000 / 310193
#      237000 / 310193
#      238000 / 310193
#      239000 / 310193
#      240000 / 310193
#      241000 / 310193
#      242000 / 310193
#      243000 / 310193
#      244000 / 310193
#      245000 / 310193
#      246000 / 310193
#      247000 / 310193
#      248000 / 310193
#      249000 / 310193
#      250000 / 310193
#      251000 / 310193
#      252000 / 310193
#      253000 / 310193
#      254000 / 310193
#      255000 / 310193
#      256000 / 310193
#      257000 / 310193
#      258000 / 310193
#      259000 / 310193
#      260000 / 310193
#      261000 / 310193
#      262000 / 310193
#      263000 / 310193
#      264000 / 310193
#      265000 / 310193
#      266000 / 310193
#      267000 / 310193
#      268000 / 310193
#      269000 / 310193
#      270000 / 310193
#      271000 / 310193
#      272000 / 310193
#      273000 / 310193
#      274000 / 310193
#      275000 / 310193
#      276000 / 310193
#      277000 / 310193
#      278000 / 310193
#      279000 / 310193
#      280000 / 310193
#      281000 / 310193
#      282000 / 310193
#      283000 / 310193
#      284000 / 310193
#      285000 / 310193
#      286000 / 310193
#      287000 / 310193
#      288000 / 310193
#      289000 / 310193
#      290000 / 310193
#      291000 / 310193
#      292000 / 310193
#      293000 / 310193
#      294000 / 310193
#      295000 / 310193
#      296000 / 310193
#      297000 / 310193
#      298000 / 310193
#      299000 / 310193
#      300000 / 310193
#      301000 / 310193
#      302000 / 310193
#      303000 / 310193
#      304000 / 310193
#      305000 / 310193
#      306000 / 310193
#      307000 / 310193
#      308000 / 310193
#      309000 / 310193
#      310000 / 310193
# CHN-Chengdu_ADM-3_1 Anyue County
#      0 / 11513
#      1000 / 11513
#      2000 / 11513
#      3000 / 11513
#      4000 / 11513
#      5000 / 11513
#      6000 / 11513
#      7000 / 11513
#      8000 / 11513
#      9000 / 11513
#      10000 / 11513
#      11000 / 11513
# CHN-Chengdu_ADM-3_2 Renshou County
#      0 / 25450
#      1000 / 25450
#      2000 / 25450
#      3000 / 25450
#      4000 / 25450
#      5000 / 25450
#      6000 / 25450
#      7000 / 25450
#      8000 / 25450
#      9000 / 25450
#      10000 / 25450
#      11000 / 25450
#      12000 / 25450
#      13000 / 25450
#      14000 / 25450
#      15000 / 25450
#      16000 / 25450
#      17000 / 25450
#      18000 / 25450
#      19000 / 25450
#      20000 / 25450
#      21000 / 25450
#      22000 / 25450
#      23000 / 25450
#      24000 / 25450
#      25000 / 25450
# CHN-Chengdu_ADM-3_3 Xindu District
#      0 / 10963
#      1000 / 10963
#      2000 / 10963
#      3000 / 10963
#      4000 / 10963
#      5000 / 10963
#      6000 / 10963
#      7000 / 10963
#      8000 / 10963
#      9000 / 10963
#      10000 / 10963
# CHN-Chengdu_ADM-3_4 Jinniu District
#      0 / 2986
#      1000 / 2986
#      2000 / 2986
# CHN-Chengdu_ADM-3_5 Shuangliu County
#      0 / 13794
#      1000 / 13794
#      2000 / 13794
#      3000 / 13794
#      4000 / 13794
#      5000 / 13794
#      6000 / 13794
#      7000 / 13794
#      8000 / 13794
#      9000 / 13794
#      10000 / 13794
#      11000 / 13794
#      12000 / 13794
#      13000 / 13794
# CHN-Chengdu_ADM-3_6 Hongya County
#      0 / 2291
#      1000 / 2291
#      2000 / 2291
# CHN-Chengdu_ADM-3_7 Xinjin County
#      0 / 4564
#      3000 / 4564
#      4000 / 4564
# CHN-Chengdu_ADM-3_8 Zhongjiang County
#      0 / 17663
#      1000 / 17663
#      2000 / 17663
#      3000 / 17663
#      4000 / 17663
#      5000 / 17663
#      6000 / 17663
#      7000 / 17663
#      8000 / 17663
#      9000 / 17663
#      10000 / 17663
#      11000 / 17663
#      12000 / 17663
#      13000 / 17663
#      14000 / 17663
#      15000 / 17663
#      16000 / 17663
#      17000 / 17663
# CHN-Chengdu_ADM-3_9 Wuhou District
#      0 / 3550
#      1000 / 3550
#      2000 / 3550
#      3000 / 3550
# CHN-Chengdu_ADM-3_10 Yanjiang District
#      0 / 23723
#      1000 / 23723
#      2000 / 23723
#      3000 / 23723
#      4000 / 23723
#      5000 / 23723
#      6000 / 23723
#      7000 / 23723
#      8000 / 23723
#      9000 / 23723
#      10000 / 23723
#      11000 / 23723
#      12000 / 23723
#      13000 / 23723
#      14000 / 23723
#      15000 / 23723
#      16000 / 23723
#      17000 / 23723
#      18000 / 23723
#      19000 / 23723
#      20000 / 23723
#      21000 / 23723
#      22000 / 23723
#      23000 / 23723
# CHN-Chengdu_ADM-3_11 Shifang City
#      0 / 9839
#      1000 / 9839
#      2000 / 9839
#      3000 / 9839
#      4000 / 9839
#      5000 / 9839
#      6000 / 9839
#      7000 / 9839
#      8000 / 9839
#      9000 / 9839
# CHN-Chengdu_ADM-3_12 Qionglai City
#      0 / 6865
#      1000 / 6865
#      2000 / 6865
#      3000 / 6865
#      4000 / 6865
#      5000 / 6865
#      6000 / 6865
# CHN-Chengdu_ADM-3_13 Qingyang District
#      0 / 1772
#      1000 / 1772
# CHN-Chengdu_ADM-3_14 Qingshen County
#      0 / 3663
#      1000 / 3663
#      2000 / 3663
#      3000 / 3663
# CHN-Chengdu_ADM-3_15 Qingbaijiang District
#      0 / 7247
#      1000 / 7247
#      2000 / 7247
#      3000 / 7247
#      4000 / 7247
#      5000 / 7247
#      6000 / 7247
#      7000 / 7247
# CHN-Chengdu_ADM-3_16 Wenjiang District
#      0 / 2643
#      1000 / 2643
#      2000 / 2643
# CHN-Chengdu_ADM-3_17 Pi County
#      0 / 5703
#      1000 / 5703
#      2000 / 5703
#      3000 / 5703
#      4000 / 5703
#      5000 / 5703
# CHN-Chengdu_ADM-3_18 Pengzhou City
#      0 / 15283
#      1000 / 15283
#      2000 / 15283
#      3000 / 15283
#      4000 / 15283
#      5000 / 15283
#      6000 / 15283
#      7000 / 15283
#      8000 / 15283
#      9000 / 15283
#      10000 / 15283
#      11000 / 15283
#      12000 / 15283
#      13000 / 15283
#      14000 / 15283
#      15000 / 15283
# CHN-Chengdu_ADM-3_19 Pengshan County
#      0 / 6002
#      1000 / 6002
#      2000 / 6002
#      3000 / 6002
#      4000 / 6002
#      5000 / 6002
#      6000 / 6002
# CHN-Chengdu_ADM-3_20 Mianzhu City
#      0 / 12083
#      1000 / 12083
#      2000 / 12083
#      3000 / 12083
#      4000 / 12083
#      5000 / 12083
#      6000 / 12083
#      7000 / 12083
#      8000 / 12083
#      9000 / 12083
#      10000 / 12083
#      11000 / 12083
#      12000 / 12083
# CHN-Chengdu_ADM-3_21 Luojiang County
#      0 / 8681
#      1000 / 8681
#      2000 / 8681
#      3000 / 8681
#      4000 / 8681
#      5000 / 8681
#      6000 / 8681
#      7000 / 8681
#      8000 / 8681
# CHN-Chengdu_ADM-3_22 Longquanyi District
#      0 / 7236
#      1000 / 7236
#      2000 / 7236
#      3000 / 7236
#      4000 / 7236
#      5000 / 7236
#      6000 / 7236
#      7000 / 7236
# CHN-Chengdu_ADM-3_23 Pujiang County
#      0 / 2503
#      1000 / 2503
#      2000 / 2503
# CHN-Chengdu_ADM-3_24 Jintang County
#      0 / 12345
#      1000 / 12345
#      2000 / 12345
#      3000 / 12345
#      4000 / 12345
#      5000 / 12345
#      6000 / 12345
#      7000 / 12345
#      8000 / 12345
#      9000 / 12345
#      10000 / 12345
#      11000 / 12345
#      12000 / 12345
# CHN-Chengdu_ADM-3_25 Jinjiang District
#      0 / 1334
#      1000 / 1334
# CHN-Chengdu_ADM-3_26 Jingyang District
#      0 / 9710
#      1000 / 9710
#      2000 / 9710
#      3000 / 9710
#      4000 / 9710
#      5000 / 9710
#      6000 / 9710
#      7000 / 9710
#      8000 / 9710
#      9000 / 9710
# CHN-Chengdu_ADM-3_27 Jianyang City
#      0 / 18312
#      1000 / 18312
#      2000 / 18312
#      3000 / 18312
#      4000 / 18312
#      5000 / 18312
#      6000 / 18312
#      7000 / 18312
#      8000 / 18312
#      9000 / 18312
#      10000 / 18312
#      11000 / 18312
#      12000 / 18312
#      13000 / 18312
#      14000 / 18312
#      15000 / 18312
#      16000 / 18312
#      17000 / 18312
#      18000 / 18312
# CHN-Chengdu_ADM-3_28 Lezhi County
#      0 / 10547
#      1000 / 10547
#      2000 / 10547
#      3000 / 10547
#      4000 / 10547
#      5000 / 10547
#      6000 / 10547
#      7000 / 10547
#      8000 / 10547
#      9000 / 10547
#      10000 / 10547
# CHN-Chengdu_ADM-3_29 Dujiangyan City
#      0 / 3679
#      1000 / 3679
#      2000 / 3679
#      3000 / 3679
# CHN-Chengdu_ADM-3_30 Dongpo District
#      0 / 23258
#      1000 / 23258
#      2000 / 23258
#      3000 / 23258
#      4000 / 23258
#      5000 / 23258
#      6000 / 23258
#      7000 / 23258
#      8000 / 23258
#      9000 / 23258
#      10000 / 23258
#      11000 / 23258
#      12000 / 23258
#      13000 / 23258
#      14000 / 23258
#      15000 / 23258
#      16000 / 23258
#      17000 / 23258
#      18000 / 23258
#      19000 / 23258
#      20000 / 23258
#      21000 / 23258
#      22000 / 23258
#      23000 / 23258
# CHN-Chengdu_ADM-3_31 Chongzhou City
#      0 / 7389
#      1000 / 7389
#      2000 / 7389
#      3000 / 7389
#      4000 / 7389
#      5000 / 7389
#      6000 / 7389
#      7000 / 7389
# CHN-Chengdu_ADM-3_32 Chenghua District
#      0 / 2834
#      1000 / 2834
#      2000 / 2834
# CHN-Chengdu_ADM-3_33 Guanghan City
#      0 / 10454
#      1000 / 10454
#      2000 / 10454
#      3000 / 10454
#      4000 / 10454
#      5000 / 10454
#      6000 / 10454
#      7000 / 10454
#      8000 / 10454
#      9000 / 10454
#      10000 / 10454
# CHN-Chengdu_ADM-3_34 Dayi County
#      0 / 5587
#      1000 / 5587
#      2000 / 5587
#      3000 / 5587
#      4000 / 5587
#      5000 / 5587
# CHN-Chengdu_ADM-3_35 Danleng County
#      0 / 1849
#      1000 / 1849
# CHN-Chongqing_ADM-1_1 CHN-Chongqing
#      0 / 211442
#      1000 / 211442
#      2000 / 211442
#      3000 / 211442
#      4000 / 211442
#      5000 / 211442
#      6000 / 211442
#      7000 / 211442
#      8000 / 211442
#      9000 / 211442
#      10000 / 211442
#      11000 / 211442
#      12000 / 211442
#      13000 / 211442
#      14000 / 211442
#      15000 / 211442
#      16000 / 211442
#      17000 / 211442
#      18000 / 211442
#      19000 / 211442
#      20000 / 211442
#      21000 / 211442
#      22000 / 211442
#      23000 / 211442
#      24000 / 211442
#      25000 / 211442
#      26000 / 211442
#      27000 / 211442
#      28000 / 211442
#      29000 / 211442
#      30000 / 211442
#      31000 / 211442
#      32000 / 211442
#      33000 / 211442
#      34000 / 211442
#      35000 / 211442
#      36000 / 211442
#      37000 / 211442
#      38000 / 211442
#      39000 / 211442
#      40000 / 211442
#      41000 / 211442
#      42000 / 211442
#      43000 / 211442
#      44000 / 211442
#      45000 / 211442
#      46000 / 211442
#      47000 / 211442
#      48000 / 211442
#      49000 / 211442
#      50000 / 211442
#      51000 / 211442
#      52000 / 211442
#      53000 / 211442
#      54000 / 211442
#      55000 / 211442
#      56000 / 211442
#      57000 / 211442
#      58000 / 211442
#      59000 / 211442
#      60000 / 211442
#      61000 / 211442
#      62000 / 211442
#      63000 / 211442
#      64000 / 211442
#      65000 / 211442
#      66000 / 211442
#      67000 / 211442
#      68000 / 211442
#      69000 / 211442
#      70000 / 211442
#      71000 / 211442
#      72000 / 211442
#      73000 / 211442
#      74000 / 211442
#      75000 / 211442
#      76000 / 211442
#      77000 / 211442
#      78000 / 211442
#      79000 / 211442
#      80000 / 211442
#      81000 / 211442
#      82000 / 211442
#      83000 / 211442
#      84000 / 211442
#      85000 / 211442
#      86000 / 211442
#      87000 / 211442
#      88000 / 211442
#      89000 / 211442
#      90000 / 211442
#      91000 / 211442
#      92000 / 211442
#      93000 / 211442
#      94000 / 211442
#      95000 / 211442
#      96000 / 211442
#      97000 / 211442
#      98000 / 211442
#      99000 / 211442
#      100000 / 211442
#      101000 / 211442
#      102000 / 211442
#      103000 / 211442
#      104000 / 211442
#      105000 / 211442
#      106000 / 211442
#      107000 / 211442
#      108000 / 211442
#      109000 / 211442
#      110000 / 211442
#      111000 / 211442
#      112000 / 211442
#      113000 / 211442
#      114000 / 211442
#      115000 / 211442
#      116000 / 211442
#      117000 / 211442
#      118000 / 211442
#      119000 / 211442
#      120000 / 211442
#      121000 / 211442
#      122000 / 211442
#      123000 / 211442
#      124000 / 211442
#      125000 / 211442
#      126000 / 211442
#      127000 / 211442
#      128000 / 211442
#      129000 / 211442
#      130000 / 211442
#      131000 / 211442
#      132000 / 211442
#      133000 / 211442
#      134000 / 211442
#      135000 / 211442
#      136000 / 211442
#      137000 / 211442
#      138000 / 211442
#      139000 / 211442
#      140000 / 211442
#      141000 / 211442
#      142000 / 211442
#      143000 / 211442
#      144000 / 211442
#      145000 / 211442
#      146000 / 211442
#      147000 / 211442
#      148000 / 211442
#      149000 / 211442
#      150000 / 211442
#      151000 / 211442
#      152000 / 211442
#      153000 / 211442
#      154000 / 211442
#      155000 / 211442
#      156000 / 211442
#      157000 / 211442
#      158000 / 211442
#      159000 / 211442
#      160000 / 211442
#      161000 / 211442
#      162000 / 211442
#      163000 / 211442
#      164000 / 211442
#      165000 / 211442
#      166000 / 211442
#      167000 / 211442
#      168000 / 211442
#      169000 / 211442
#      170000 / 211442
#      171000 / 211442
#      172000 / 211442
#      173000 / 211442
#      174000 / 211442
#      175000 / 211442
#      176000 / 211442
#      177000 / 211442
#      178000 / 211442
#      179000 / 211442
#      180000 / 211442
#      181000 / 211442
#      182000 / 211442
#      183000 / 211442
#      184000 / 211442
#      185000 / 211442
#      186000 / 211442
#      187000 / 211442
#      188000 / 211442
#      189000 / 211442
#      190000 / 211442
#      191000 / 211442
#      192000 / 211442
#      193000 / 211442
#      194000 / 211442
#      195000 / 211442
#      196000 / 211442
#      197000 / 211442
#      198000 / 211442
#      199000 / 211442
#      200000 / 211442
#      201000 / 211442
#      202000 / 211442
#      203000 / 211442
#      204000 / 211442
#      205000 / 211442
#      206000 / 211442
#      207000 / 211442
#      208000 / 211442
#      209000 / 211442
#      210000 / 211442
#      211000 / 211442
# CHN-Chongqing_ADM-3_1 Wulong District
#      0 / 1740
#      1000 / 1740
# CHN-Chongqing_ADM-3_2 Beibei District
#      0 / 2067
#      1000 / 2067
#      2000 / 2067
# CHN-Chongqing_ADM-3_3 Fengdu County
#      0 / 4984
#      1000 / 4984
#      2000 / 4984
#      3000 / 4984
#      4000 / 4984
# CHN-Chongqing_ADM-3_4 Fengjie
#      0 / 3605
#      1000 / 3605
#      2000 / 3605
#      3000 / 3605
# CHN-Chongqing_ADM-3_5 Fuling District
#      0 / 9852
#      1000 / 9852
#      2000 / 9852
#      3000 / 9852
#      4000 / 9852
#      5000 / 9852
#      6000 / 9852
#      7000 / 9852
#      8000 / 9852
#      9000 / 9852
# CHN-Chongqing_ADM-3_6 Jiangjin District
#      0 / 13723
#      1000 / 13723
#      2000 / 13723
#      3000 / 13723
#      4000 / 13723
#      5000 / 13723
#      6000 / 13723
#      7000 / 13723
#      8000 / 13723
#      9000 / 13723
#      10000 / 13723
#      11000 / 13723
#      12000 / 13723
#      13000 / 13723
# CHN-Chongqing_ADM-3_7 Nan'an District
#      0 / 1874
#      1000 / 1874
# CHN-Chongqing_ADM-3_8 Pengshui Miao and Tujia Autonomous County
#      0 / 2349
#      1000 / 2349
#      2000 / 2349
# CHN-Chongqing_ADM-3_9 Yunyang
#      0 / 2875
#      1000 / 2875
#      2000 / 2875
# CHN-Chongqing_ADM-3_10 Wanzhou
#      0 / 4862
#      1000 / 4862
#      2000 / 4862
#      3000 / 4862
#      4000 / 4862
# CHN-Chongqing_ADM-3_11 Kaizhou District
#      0 / 4094
#      1000 / 4094
#      2000 / 4094
#      3000 / 4094
#      4000 / 4094
# CHN-Chongqing_ADM-3_12 Nanchuan District
#      0 / 3825
#      1000 / 3825
#      2000 / 3825
#      3000 / 3825
# CHN-Chongqing_ADM-3_13 Youyang Miao and Tujia Autonomous County
#      0 / 4063
#      1000 / 4063
#      2000 / 4063
#      3000 / 4063
#      4000 / 4063
# CHN-Chongqing_ADM-3_14 Xiushan (Miao and Tujia) Autonomous County
#      0 / 6092
#      1000 / 6092
#      2000 / 6092
#      3000 / 6092
#      4000 / 6092
#      5000 / 6092
#      6000 / 6092
# CHN-Chongqing_ADM-3_15 Yubei District
#      0 / 5826
#      1000 / 5826
#      2000 / 5826
#      3000 / 5826
#      4000 / 5826
#      5000 / 5826
# CHN-Chongqing_ADM-3_16 Wuxi
#      0 / 1850
#      1000 / 1850
# CHN-Chongqing_ADM-3_17 Tongnan
#      0 / 6328
#      1000 / 6328
#      2000 / 6328
#      3000 / 6328
#      4000 / 6328
#      5000 / 6328
#      6000 / 6328
# CHN-Chongqing_ADM-3_18 Hechuan District
#      0 / 17634
#      1000 / 17634
#      2000 / 17634
#      3000 / 17634
#      4000 / 17634
#      5000 / 17634
#      6000 / 17634
#      7000 / 17634
#      8000 / 17634
#      9000 / 17634
#      10000 / 17634
#      11000 / 17634
#      12000 / 17634
#      13000 / 17634
#      14000 / 17634
#      15000 / 17634
#      16000 / 17634
#      17000 / 17634
# CHN-Chongqing_ADM-3_19 Qianjiang District
#      0 / 1757
#      1000 / 1757
# CHN-Chongqing_ADM-3_20 Qijiang District
#      0 / 4125
#      1000 / 4125
#      2000 / 4125
#      3000 / 4125
#      4000 / 4125
# CHN-Chongqing_ADM-3_21 Shapingba District
#      0 / 2963
#      1000 / 2963
#      2000 / 2963
# CHN-Chongqing_ADM-3_22 Wushan
#      0 / 2627
#      1000 / 2627
#      2000 / 2627
# CHN-Chongqing_ADM-3_23 Shizhu (Tujia) Autonomous County
#      0 / 1950
#      1000 / 1950
# CHN-Chongqing_ADM-3_24 Tongliang District
#      0 / 9754
#      1000 / 9754
#      2000 / 9754
#      3000 / 9754
#      4000 / 9754
#      5000 / 9754
#      6000 / 9754
#      7000 / 9754
#      8000 / 9754
#      9000 / 9754
# CHN-Chongqing_ADM-3_25 Jiulongpo District
#      0 / 4075
#      1000 / 4075
#      2000 / 4075
#      3000 / 4075
#      4000 / 4075
# CHN-Chongqing_ADM-3_26 Zhong
#      0 / 3275
#      1000 / 3275
#      2000 / 3275
#      3000 / 3275
# CHN-Chongqing_ADM-3_27 Yongchuan District
#      0 / 21531
#      1000 / 21531
#      2000 / 21531
#      3000 / 21531
#      4000 / 21531
#      5000 / 21531
#      6000 / 21531
#      7000 / 21531
#      8000 / 21531
#      9000 / 21531
#      10000 / 21531
#      11000 / 21531
#      12000 / 21531
#      13000 / 21531
#      14000 / 21531
#      15000 / 21531
#      16000 / 21531
#      17000 / 21531
#      18000 / 21531
#      19000 / 21531
#      20000 / 21531
#      21000 / 21531
# CHN-Chongqing_ADM-3_28 Rongchang District
#      0 / 13959
#      1000 / 13959
#      2000 / 13959
#      3000 / 13959
#      4000 / 13959
#      5000 / 13959
#      6000 / 13959
#      7000 / 13959
#      8000 / 13959
#      9000 / 13959
#      10000 / 13959
#      11000 / 13959
#      12000 / 13959
#      13000 / 13959
# CHN-Chongqing_ADM-3_29 Jiangbei District
#      0 / 2022
#      1000 / 2022
#      2000 / 2022
# CHN-Chongqing_ADM-3_30 Liangping
#      0 / 7158
#      1000 / 7158
#      2000 / 7158
#      3000 / 7158
#      4000 / 7158
#      5000 / 7158
#      6000 / 7158
#      7000 / 7158
# CHN-Chongqing_ADM-3_31 Dadukou District
#      0 / 966
# CHN-Chongqing_ADM-3_32 Chengkou County
#      0 / 143
# CHN-Chongqing_ADM-3_33 Changshou District
#      0 / 7994
#      1000 / 7994
#      2000 / 7994
#      3000 / 7994
#      4000 / 7994
#      5000 / 7994
#      6000 / 7994
#      7000 / 7994
# CHN-Chongqing_ADM-3_34 Bishan District
#      0 / 5065
#      1000 / 5065
#      2000 / 5065
#      3000 / 5065
#      4000 / 5065
#      5000 / 5065
# CHN-Chongqing_ADM-3_35 Banan District
#      0 / 3388
#      1000 / 3388
#      2000 / 3388
#      3000 / 3388
# CHN-Chongqing_ADM-3_36 Dianjiang County
#      0 / 10361
#      1000 / 10361
#      2000 / 10361
#      3000 / 10361
#      4000 / 10361
#      5000 / 10361
#      6000 / 10361
#      7000 / 10361
#      8000 / 10361
#      9000 / 10361
#      10000 / 10361
# CHN-Chongqing_ADM-3_37 Dazu District
#      0 / 11532
#      1000 / 11532
#      2000 / 11532
#      3000 / 11532
#      4000 / 11532
#      5000 / 11532
#      6000 / 11532
#      7000 / 11532
#      8000 / 11532
#      9000 / 11532
#      10000 / 11532
#      11000 / 11532
# CHN-Chongqing_ADM-3_38 Yuzhong District
#      0 / 426
# CHN-Ningbo_ADM-3-union_1 CHN-Ningbo
#      0 / 73590
#      1000 / 73590
#      2000 / 73590
#      3000 / 73590
#      4000 / 73590
#      5000 / 73590
#      6000 / 73590
#      7000 / 73590
#      8000 / 73590
#      9000 / 73590
#      10000 / 73590
#      11000 / 73590
#      12000 / 73590
#      13000 / 73590
#      14000 / 73590
#      15000 / 73590
#      16000 / 73590
#      17000 / 73590
#      18000 / 73590
#      19000 / 73590
#      20000 / 73590
#      21000 / 73590
#      22000 / 73590
#      23000 / 73590
#      24000 / 73590
#      25000 / 73590
#      26000 / 73590
#      27000 / 73590
#      28000 / 73590
#      29000 / 73590
#      30000 / 73590
#      31000 / 73590
#      32000 / 73590
#      33000 / 73590
#      34000 / 73590
#      35000 / 73590
#      36000 / 73590
#      37000 / 73590
#      38000 / 73590
#      39000 / 73590
#      40000 / 73590
#      41000 / 73590
#      42000 / 73590
#      43000 / 73590
#      44000 / 73590
#      45000 / 73590
#      46000 / 73590
#      47000 / 73590
#      48000 / 73590
#      49000 / 73590
#      50000 / 73590
#      51000 / 73590
#      52000 / 73590
#      53000 / 73590
#      54000 / 73590
#      55000 / 73590
#      56000 / 73590
#      57000 / 73590
#      58000 / 73590
#      59000 / 73590
#      60000 / 73590
#      61000 / 73590
#      62000 / 73590
#      63000 / 73590
#      64000 / 73590
#      65000 / 73590
#      66000 / 73590
#      67000 / 73590
#      68000 / 73590
#      69000 / 73590
#      70000 / 73590
#      71000 / 73590
#      72000 / 73590
#      73000 / 73590
# CHN-Ningbo_ADM-3_1 Ninghai County
#      0 / 7604
#      1000 / 7604
#      2000 / 7604
#      3000 / 7604
#      4000 / 7604
#      5000 / 7604
#      6000 / 7604
#      7000 / 7604
# CHN-Ningbo_ADM-3_2 Fenghua District
#      0 / 5205
#      1000 / 5205
#      2000 / 5205
#      3000 / 5205
#      4000 / 5205
#      5000 / 5205
# CHN-Ningbo_ADM-3_3 Yinzhou District
#      0 / 8393
#      1000 / 8393
#      2000 / 8393
#      3000 / 8393
#      4000 / 8393
#      5000 / 8393
#      6000 / 8393
#      7000 / 8393
#      8000 / 8393
# CHN-Ningbo_ADM-3_4 Yuyao City
#      0 / 11256
#      1000 / 11256
#      2000 / 11256
#      3000 / 11256
#      4000 / 11256
#      5000 / 11256
#      6000 / 11256
#      7000 / 11256
#      8000 / 11256
#      9000 / 11256
#      10000 / 11256
#      11000 / 11256
# CHN-Ningbo_ADM-3_5 Zhenhai District
#      0 / 3430
#      1000 / 3430
#      2000 / 3430
#      3000 / 3430
# CHN-Ningbo_ADM-3_6 Xiangshan County
#      0 / 7568
#      1000 / 7568
#      2000 / 7568
#      3000 / 7568
#      4000 / 7568
#      5000 / 7568
#      6000 / 7568
#      7000 / 7568
# CHN-Ningbo_ADM-3_7 Jiangbei District
#      0 / 3311
#      1000 / 3311
#      2000 / 3311
#      3000 / 3311
# CHN-Ningbo_ADM-3_8 Haishu District
#      0 / 5081
#      1000 / 5081
#      2000 / 5081
#      3000 / 5081
#      4000 / 5081
#      5000 / 5081
# CHN-Ningbo_ADM-3_9 Cixi City
#      0 / 15573
#      1000 / 15573
#      2000 / 15573
#      3000 / 15573
#      4000 / 15573
#      5000 / 15573
#      6000 / 15573
#      7000 / 15573
#      8000 / 15573
#      9000 / 15573
#      10000 / 15573
#      11000 / 15573
#      12000 / 15573
#      13000 / 15573
#      14000 / 15573
#      15000 / 15573
# CHN-Ningbo_ADM-3_10 Beilun District
#      0 / 6354
#      1000 / 6354
#      2000 / 6354
#      3000 / 6354
#      4000 / 6354
#      5000 / 6354
#      6000 / 6354
# IDN-Jakarta_ADM-4-union_1 IDN-Jakarta
#      0 / 8744
#      1000 / 8744
#      2000 / 8744
#      3000 / 8744
#      4000 / 8744
#      5000 / 8744
#      6000 / 8744
#      7000 / 8744
#      8000 / 8744
# IDN-Jakarta_ADM-4_1 Cikini
#      0 / 8
# IDN-Jakarta_ADM-4_2 Gondangdia
#      0 / 27
# IDN-Jakarta_ADM-4_3 Karet
#      0 / 15
# IDN-Jakarta_ADM-4_4 Serdang
#      0 / 1
# IDN-Jakarta_ADM-4_5 Duri Selatan
#      0 / 2
# IDN-Jakarta_ADM-4_6 Cempaka Putih Timur
#      0 / 38
# IDN-Jakarta_ADM-4_7 Kebon Kelapa
#      0 / 9
# IDN-Jakarta_ADM-4_8 Tanjung Duren Selatan
#      0 / 11
# IDN-Jakarta_ADM-4_9 Setiabudi
#      0 / 11
# IDN-Jakarta_ADM-4_10 Guntur
#      0 / 11
# IDN-Jakarta_ADM-4_11 Pasar Baru
#      0 / 27
# IDN-Jakarta_ADM-4_12 Kuningan Barat
#      0 / 20
# IDN-Jakarta_ADM-4_13 Kampung Rawa
# IDN-Jakarta_ADM-4_14 Kebon Bawang
#      0 / 15
# IDN-Jakarta_ADM-4_15 Kebon Kacang
#      0 / 2
# IDN-Jakarta_ADM-4_16 Slipi
#      0 / 9
# IDN-Jakarta_ADM-4_17 Jati Pulo
#      0 / 4
# IDN-Jakarta_ADM-4_18 Cijantung
#      0 / 25
# IDN-Jakarta_ADM-4_19 Petojo Selatan
#      0 / 14
# IDN-Jakarta_ADM-4_20 Paseban
#      0 / 4
# IDN-Jakarta_ADM-4_21 Mampang Prapatan
#      0 / 6
# IDN-Jakarta_ADM-4_22 Kebagusan
#      0 / 64
# IDN-Jakarta_ADM-4_23 Kebon Sirih
#      0 / 11
# IDN-Jakarta_ADM-4_24 Petojo Utara
#      0 / 13
# IDN-Jakarta_ADM-4_25 Klender
#      0 / 27
# IDN-Jakarta_ADM-4_26 Menteng
#      0 / 64
# IDN-Jakarta_ADM-4_27 Pesanggrahan
#      0 / 40
# IDN-Jakarta_ADM-4_28 Jembatan Lima
#      0 / 1
# IDN-Jakarta_ADM-4_29 Menteng Dalam
#      0 / 36
# IDN-Jakarta_ADM-4_30 Meruya Utara
#      0 / 97
# IDN-Jakarta_ADM-4_31 Glodok
# IDN-Jakarta_ADM-4_32 Keagungan
# IDN-Jakarta_ADM-4_33 Tomang
#      0 / 16
# IDN-Jakarta_ADM-4_34 Mangga Besar
#      0 / 3
# IDN-Jakarta_ADM-4_35 Kalianyar
# IDN-Jakarta_ADM-4_36 Tanjung Barat
#      0 / 81
# IDN-Jakarta_ADM-4_37 Kayu Putih
#      0 / 53
# IDN-Jakarta_ADM-4_38 Tegal Parang
#      0 / 6
# IDN-Jakarta_ADM-4_39 Kenari
#      0 / 7
# IDN-Jakarta_ADM-4_40 Pegangsaan
#      0 / 17
# IDN-Jakarta_ADM-4_41 Taman Mini Indonesia Indah (TMII)
#      0 / 10
# IDN-Jakarta_ADM-4_42 Cempaka Putih Barat
#      0 / 10
# IDN-Jakarta_ADM-4_43 Palmeriam
#      0 / 5
# IDN-Jakarta_ADM-4_44 Rawa Terate
#      0 / 56
# IDN-Jakarta_ADM-4_45 Jatinegara Kaum
#      0 / 21
# IDN-Jakarta_ADM-4_46 Pulo Gadung
#      0 / 23
# IDN-Jakarta_ADM-4_47 Jelambar Baru
#      0 / 13
# IDN-Jakarta_ADM-4_48 Kebon Jeruk
#      0 / 58
# IDN-Jakarta_ADM-4_49 Kedoya Selatan
#      0 / 41
# IDN-Jakarta_ADM-4_50 Jatinegara
#      0 / 109
# IDN-Jakarta_ADM-4_51 Bungur
#      0 / 3
# IDN-Jakarta_ADM-4_52 Susukan
#      0 / 32
# IDN-Jakarta_ADM-4_53 Ciracas
#      0 / 60
# IDN-Jakarta_ADM-4_54 Baru
#      0 / 18
# IDN-Jakarta_ADM-4_55 Bale Kambang
#      0 / 26
# IDN-Jakarta_ADM-4_56 Sukapura
#      0 / 86
# IDN-Jakarta_ADM-4_57 Malaka Jaya
#      0 / 9
# IDN-Jakarta_ADM-4_58 Malaka Sari
#      0 / 23
# IDN-Jakarta_ADM-4_59 Kedaung Kali Angke
#      0 / 36
# IDN-Jakarta_ADM-4_60 Krukut
# IDN-Jakarta_ADM-4_61 Warakas
# IDN-Jakarta_ADM-4_62 Rawa Badak Utara
#      0 / 13
# IDN-Jakarta_ADM-4_63 Duren Tiga
#      0 / 54
# IDN-Jakarta_ADM-4_64 Pancoran
#      0 / 19
# IDN-Jakarta_ADM-4_65 Kembangan Utara
#      0 / 77
# IDN-Jakarta_ADM-4_66 Pejaten Barat
#      0 / 89
# IDN-Jakarta_ADM-4_67 Galur
# IDN-Jakarta_ADM-4_68 Wijaya Kusuma
#      0 / 20
# IDN-Jakarta_ADM-4_69 Kedoya Utara
#      0 / 32
# IDN-Jakarta_ADM-4_70 Kalibata
#      0 / 37
# IDN-Jakarta_ADM-4_71 Makasar
#      0 / 16
# IDN-Jakarta_ADM-4_72 Pondok Kopi
#      0 / 31
# IDN-Jakarta_ADM-4_73 Penggilingan
#      0 / 50
# IDN-Jakarta_ADM-4_74 Kebon Melati
#      0 / 21
# IDN-Jakarta_ADM-4_75 Cililitan
#      0 / 28
# IDN-Jakarta_ADM-4_76 Kramat Jati
#      0 / 19
# IDN-Jakarta_ADM-4_77 Pejaten Timur
#      0 / 53
# IDN-Jakarta_ADM-4_78 Gambir
#      0 / 40
# IDN-Jakarta_ADM-4_79 Kampung Bali
#      0 / 9
# IDN-Jakarta_ADM-4_80 Pengadegan
#      0 / 16
# IDN-Jakarta_ADM-4_81 Gunung
#      0 / 37
# IDN-Jakarta_ADM-4_82 Cawang
#      0 / 33
# IDN-Jakarta_ADM-4_83 Rawajati
#      0 / 34
# IDN-Jakarta_ADM-4_84 Kuningan Timur
#      0 / 55
# IDN-Jakarta_ADM-4_85 Manggarai Selatan
# IDN-Jakarta_ADM-4_86 Cakung Barat
#      0 / 47
# IDN-Jakarta_ADM-4_87 Cipinang Cempedak
#      0 / 15
# IDN-Jakarta_ADM-4_88 Bidara Cina
#      0 / 20
# IDN-Jakarta_ADM-4_89 Gedong
#      0 / 38
# IDN-Jakarta_ADM-4_90 Kebon Pala
#      0 / 30
# IDN-Jakarta_ADM-4_91 Halim Perdana Kusuma
#      0 / 104
# IDN-Jakarta_ADM-4_92 Manggarai
#      0 / 25
# IDN-Jakarta_ADM-4_93 Pasar Manggis
#      0 / 8
# IDN-Jakarta_ADM-4_94 Kwitang
#      0 / 1
# IDN-Jakarta_ADM-4_95 Kebon Baru
#      0 / 14
# IDN-Jakarta_ADM-4_96 Pademangan Barat
#      0 / 15
# IDN-Jakarta_ADM-4_97 Cipinang Besar Selatan
#      0 / 22
# IDN-Jakarta_ADM-4_98 Cipinang Besar Utara
#      0 / 4
# IDN-Jakarta_ADM-4_99 Rawa Buaya
#      0 / 45
# IDN-Jakarta_ADM-4_100 Cengkareng Timur
#      0 / 51
# IDN-Jakarta_ADM-4_101 Karet Semanggi
#      0 / 20
# IDN-Jakarta_ADM-4_102 Cikoko
#      0 / 8
# IDN-Jakarta_ADM-4_103 Tebet Barat
#      0 / 17
# IDN-Jakarta_ADM-4_104 Kapuk
#      0 / 41
# IDN-Jakarta_ADM-4_105 Petogogan
#      0 / 22
# IDN-Jakarta_ADM-4_106 Pela Mampang
#      0 / 42
# IDN-Jakarta_ADM-4_107 Jelambar
#      0 / 9
# IDN-Jakarta_ADM-4_108 Grogol
#      0 / 7
# IDN-Jakarta_ADM-4_109 Semper Barat
#      0 / 33
# IDN-Jakarta_ADM-4_110 Cakung Timur
#      0 / 118
# IDN-Jakarta_ADM-4_111 Lagoa
#      0 / 2
# IDN-Jakarta_ADM-4_112 Tugu Utara
#      0 / 19
# IDN-Jakarta_ADM-4_113 Pluit
#      0 / 68
# IDN-Jakarta_ADM-4_114 Duri Pulo
#      0 / 4
# IDN-Jakarta_ADM-4_115 Cideng
#      0 / 5
# IDN-Jakarta_ADM-4_116 Melawai
#      0 / 34
# IDN-Jakarta_ADM-4_117 Cilandak Timur
#      0 / 107
# IDN-Jakarta_ADM-4_118 Kampung Tengah
#      0 / 26
# IDN-Jakarta_ADM-4_119 Batu Ampar
#      0 / 28
# IDN-Jakarta_ADM-4_120 Tebet Timur
#      0 / 6
# IDN-Jakarta_ADM-4_121 Rambutan
#      0 / 45
# IDN-Jakarta_ADM-4_122 Pinang Ranti
#      0 / 50
# IDN-Jakarta_ADM-4_123 Rawa Bunga
#      0 / 6
# IDN-Jakarta_ADM-4_124 Kayu Manis
# IDN-Jakarta_ADM-4_125 Rawasari
#      0 / 18
# IDN-Jakarta_ADM-4_126 Utan Kayu Utara
#      0 / 9
# IDN-Jakarta_ADM-4_127 Menteng Atas
#      0 / 11
# IDN-Jakarta_ADM-4_128 Karet Kuningan
#      0 / 30
# IDN-Jakarta_ADM-4_129 Bukit Duri
#      0 / 3
# IDN-Jakarta_ADM-4_130 Bali Mester
#      0 / 5
# IDN-Jakarta_ADM-4_131 Johar Baru
#      0 / 7
# IDN-Jakarta_ADM-4_132 Tanah Tinggi
#      0 / 1
# IDN-Jakarta_ADM-4_133 Bendungan Hilir
#      0 / 27
# IDN-Jakarta_ADM-4_134 Karet Tengsin
#      0 / 29
# IDN-Jakarta_ADM-4_135 Gelora
#      0 / 50
# IDN-Jakarta_ADM-4_136 Roa Malaka
#      0 / 5
# IDN-Jakarta_ADM-4_137 Krendang
# IDN-Jakarta_ADM-4_138 Jembatan Besi
#      0 / 2
# IDN-Jakarta_ADM-4_139 Angke
#      0 / 1
# IDN-Jakarta_ADM-4_140 Duri Utara
# IDN-Jakarta_ADM-4_141 Tanah Sereal
#      0 / 1
# IDN-Jakarta_ADM-4_142 Tambora
#      0 / 1
# IDN-Jakarta_ADM-4_143 Pinangsia
#      0 / 11
# IDN-Jakarta_ADM-4_144 Penjaringan
#      0 / 20
# IDN-Jakarta_ADM-4_145 Palmerah
#      0 / 10
# IDN-Jakarta_ADM-4_146 Kemanggisan
#      0 / 30
# IDN-Jakarta_ADM-4_147 Petamburan
#      0 / 10
# IDN-Jakarta_ADM-4_148 Kota Bambu Selatan
#      0 / 4
# IDN-Jakarta_ADM-4_149 Kota Bambu Utara
#      0 / 1
# IDN-Jakarta_ADM-4_150 Kelapa Dua
#      0 / 19
# IDN-Jakarta_ADM-4_151 Sukabumi Selatan
#      0 / 17
# IDN-Jakarta_ADM-4_152 Srengseng
#      0 / 73
# IDN-Jakarta_ADM-4_153 Jati Padang
#      0 / 63
# IDN-Jakarta_ADM-4_154 Pasar Minggu
#      0 / 56
# IDN-Jakarta_ADM-4_155 Utan Panjang
#      0 / 2
# IDN-Jakarta_ADM-4_156 Harapan Mulya
#      0 / 3
# IDN-Jakarta_ADM-4_157 Cempaka Baru
#      0 / 4
# IDN-Jakarta_ADM-4_158 Sumur Batu
#      0 / 8
# IDN-Jakarta_ADM-4_159 Kebon Kosong
#      0 / 14
# IDN-Jakarta_ADM-4_160 Kemayoran
#      0 / 1
# IDN-Jakarta_ADM-4_161 Gunung Sahari Selatan
#      0 / 26
# IDN-Jakarta_ADM-4_162 Pekojan
#      0 / 2
# IDN-Jakarta_ADM-4_163 Pejagalan
#      0 / 22
# IDN-Jakarta_ADM-4_164 Cipete Selatan
#      0 / 75
# IDN-Jakarta_ADM-4_165 Gandaria Selatan
#      0 / 22
# IDN-Jakarta_ADM-4_166 Pondok Pinang
#      0 / 142
# IDN-Jakarta_ADM-4_167 Lubang Buaya
#      0 / 54
# IDN-Jakarta_ADM-4_168 Setu
#      0 / 54
# IDN-Jakarta_ADM-4_169 Cipayung
#      0 / 43
# IDN-Jakarta_ADM-4_170 Bambu Apus
#      0 / 50
# IDN-Jakarta_ADM-4_171 Utan Kayu Selatan
#      0 / 3
# IDN-Jakarta_ADM-4_172 Pisangan Baru
#      0 / 1
# IDN-Jakarta_ADM-4_173 Srengseng Sawah
#      0 / 99
# IDN-Jakarta_ADM-4_174 Cipedak
#      0 / 72
# IDN-Jakarta_ADM-4_175 Jagakarsa
#      0 / 121
# IDN-Jakarta_ADM-4_176 Ragunan
#      0 / 72
# IDN-Jakarta_ADM-4_177 Tangki
#      0 / 2
# IDN-Jakarta_ADM-4_178 Karang Anyar
#      0 / 4
# IDN-Jakarta_ADM-4_179 Gunung Sahari Utara
#      0 / 22
# IDN-Jakarta_ADM-4_180 Kartini
#      0 / 1
# IDN-Jakarta_ADM-4_181 Mangga Dua Selatan
#      0 / 15
# IDN-Jakarta_ADM-4_182 Pulo Gebang
#      0 / 104
# IDN-Jakarta_ADM-4_183 Ujung Menteng
#      0 / 72
# IDN-Jakarta_ADM-4_184 Cilandak Barat
#      0 / 188
# IDN-Jakarta_ADM-4_185 Pondok Labu
#      0 / 92
# IDN-Jakarta_ADM-4_186 Pondok Bambu
#      0 / 66
# IDN-Jakarta_ADM-4_187 Pondok Kelapa
#      0 / 118
# IDN-Jakarta_ADM-4_188 Duren Sawit
#      0 / 112
# IDN-Jakarta_ADM-4_189 Lenteng Agung
#      0 / 63
# IDN-Jakarta_ADM-4_190 Pekayon
#      0 / 43
# IDN-Jakarta_ADM-4_191 Kebon Manggis
#      0 / 11
# IDN-Jakarta_ADM-4_192 Kampung Melayu
#      0 / 2
# IDN-Jakarta_ADM-4_193 Maphar
#      0 / 2
# IDN-Jakarta_ADM-4_194 Taman Sari
#      0 / 3
# IDN-Jakarta_ADM-4_195 Cibubur
#      0 / 104
# IDN-Jakarta_ADM-4_196 Munjul
#      0 / 48
# IDN-Jakarta_ADM-4_197 Kelapa Dua Wetan
#      0 / 68
# IDN-Jakarta_ADM-4_198 Dukuh
#      0 / 37
# IDN-Jakarta_ADM-4_199 Ceger
#      0 / 43
# IDN-Jakarta_ADM-4_200 Cilangkap
#      0 / 71
# IDN-Jakarta_ADM-4_201 Pondok Ranggon
#      0 / 50
# IDN-Jakarta_ADM-4_202 Ulujami
#      0 / 40
# IDN-Jakarta_ADM-4_203 Sukabumi Utara
#      0 / 7
# IDN-Jakarta_ADM-4_204 Grogol Utara
#      0 / 77
# IDN-Jakarta_ADM-4_205 Duri Kepa
#      0 / 35
# IDN-Jakarta_ADM-4_206 Tanjung Duren Utara
#      0 / 16
# IDN-Jakarta_ADM-4_207 Kelapa Gading Timur
#      0 / 35
# IDN-Jakarta_ADM-4_208 Pegangsaan Dua
#      0 / 71
# IDN-Jakarta_ADM-4_209 Gandaria Utara
#      0 / 16
# IDN-Jakarta_ADM-4_210 Kramat Pela
#      0 / 25
# IDN-Jakarta_ADM-4_211 Grogol Selatan
#      0 / 69
# IDN-Jakarta_ADM-4_212 Cipulir
#      0 / 27
# IDN-Jakarta_ADM-4_213 Kebayoran Lama Selatan
#      0 / 32
# IDN-Jakarta_ADM-4_214 Kebayoran Lama Utara
#      0 / 43
# IDN-Jakarta_ADM-4_215 Bangka
#      0 / 93
# IDN-Jakarta_ADM-4_216 Pulo
#      0 / 12
# IDN-Jakarta_ADM-4_217 Cipete Utara
#      0 / 43
# IDN-Jakarta_ADM-4_218 Senayan
#      0 / 39
# IDN-Jakarta_ADM-4_219 Selong
#      0 / 22
# IDN-Jakarta_ADM-4_220 Rawa Barat
#      0 / 24
# IDN-Jakarta_ADM-4_221 Rawa Badak Selatan
#      0 / 16
# IDN-Jakarta_ADM-4_222 Tugu Selatan
#      0 / 19
# IDN-Jakarta_ADM-4_223 Papanggo
#      0 / 33
# IDN-Jakarta_ADM-4_224 Sungai Bambu
#      0 / 26
# IDN-Jakarta_ADM-4_225 Koja
#      0 / 14
# IDN-Jakarta_ADM-4_226 Kalibaru
#      0 / 17
# IDN-Jakarta_ADM-4_227 Cilincing
#      0 / 77
# IDN-Jakarta_ADM-4_228 Semper Timur
#      0 / 44
# IDN-Jakarta_ADM-4_229 Rorotan
#      0 / 133
# IDN-Jakarta_ADM-4_230 Tanjung Priok
#      0 / 30
# IDN-Jakarta_ADM-4_231 Pademangan Timur
#      0 / 28
# IDN-Jakarta_ADM-4_232 Sunter Agung
#      0 / 82
# IDN-Jakarta_ADM-4_233 Kamal Muara
#      0 / 95
# IDN-Jakarta_ADM-4_234 Kapuk Muara
#      0 / 106
# IDN-Jakarta_ADM-4_235 Ancol
#      0 / 127
# IDN-Jakarta_ADM-4_236 Petukangan Selatan
#      0 / 45
# IDN-Jakarta_ADM-4_237 Marunda
#      0 / 111
# IDN-Jakarta_ADM-4_238 Sunter Jaya
#      0 / 81
# IDN-Jakarta_ADM-4_239 Kelapa Gading Barat
#      0 / 132
# IDN-Jakarta_ADM-4_240 Cengkareng Barat
#      0 / 51
# IDN-Jakarta_ADM-4_241 Tegal Alur
#      0 / 54
# IDN-Jakarta_ADM-4_242 Pegadungan
#      0 / 125
# IDN-Jakarta_ADM-4_243 Bintaro
#      0 / 107
# IDN-Jakarta_ADM-4_244 Cipinang Melayu
#      0 / 44
# IDN-Jakarta_ADM-4_245 Lebak Bulus
#      0 / 78
# IDN-Jakarta_ADM-4_246 Jati
#      0 / 22
# IDN-Jakarta_ADM-4_247 Rawamangun
#      0 / 25
# IDN-Jakarta_ADM-4_248 Senen
#      0 / 19
# IDN-Jakarta_ADM-4_249 Kramat
#      0 / 2
# IDN-Jakarta_ADM-4_250 Kamal
#      0 / 79
# IDN-Jakarta_ADM-4_251 Kalideres
#      0 / 76
# IDN-Jakarta_ADM-4_252 Duri Kosambi
#      0 / 91
# IDN-Jakarta_ADM-4_253 Semanan
#      0 / 95
# IDN-Jakarta_ADM-4_254 Kembangan Selatan
#      0 / 73
# IDN-Jakarta_ADM-4_255 Meruya Selatan
#      0 / 59
# IDN-Jakarta_ADM-4_256 Joglo
#      0 / 86
# IDN-Jakarta_ADM-4_257 Petukangan Utara
#      0 / 47
# IDN-Jakarta_ADM-4_258 Cipinang Muara
#      0 / 35
# IDN-Jakarta_ADM-4_259 Cipinang
#      0 / 18
# IDN-Jakarta_ADM-4_260 Pisangan Timur
#      0 / 23
# IDN-Jakarta_ADM-4_261 Ciganjur
#      0 / 98
# IDN-Jakarta_ADM-4_262 Kalisari
#      0 / 45
# IDN-Bitung_ADM-2_1 IDN-Bitung
#      0 / 248
# IDN-Bitung_ADM-3_1 Lembeh Selatan
#      0 / 4
# IDN-Bitung_ADM-3_2 Lembeh Utara
#      0 / 5
# IDN-Bitung_ADM-3_3 Mandidir
#      0 / 79
# IDN-Bitung_ADM-3_4 Matuari
#      0 / 25
# IDN-Bitung_ADM-3_5 Girian
#      0 / 70
# IDN-Bitung_ADM-3_6 Ranuwulu
#      0 / 13
# IDN-Bitung_ADM-3_7 Maesa
#      0 / 47
# IDN-Bitung_ADM-3_8 Aertembaga
#      0 / 27
# IDN-Semarang_ADM-1_1 IDN-Semarang
#      0 / 2842
#      1000 / 2842
#      2000 / 2842
# IDN-Semarang_ADM-4_1 Cabean
#      0 / 2
# IDN-Semarang_ADM-4_2 Bojongsalaman
#      0 / 12
# IDN-Semarang_ADM-4_3 Jatingaleh
#      0 / 25
# IDN-Semarang_ADM-4_4 Karangturi
#      0 / 2
# IDN-Semarang_ADM-4_5 Karangtempel
#      0 / 8
# IDN-Semarang_ADM-4_6 Brumbungan
#      0 / 5
# IDN-Semarang_ADM-4_7 Gabahan
#      0 / 2
# IDN-Semarang_ADM-4_8 Dadapsari
#      0 / 7
# IDN-Semarang_ADM-4_9 Salaman Mloyo
#      0 / 6
# IDN-Semarang_ADM-4_10 Purwosari
#      0 / 4
# IDN-Semarang_ADM-4_11 Bulustalan
#      0 / 1
# IDN-Semarang_ADM-4_12 Plombokan
#      0 / 5
# IDN-Semarang_ADM-4_13 Lempongsari
#      0 / 17
# IDN-Semarang_ADM-4_14 Siwalan
#      0 / 12
# IDN-Semarang_ADM-4_15 Sambirejo
#      0 / 19
# IDN-Semarang_ADM-4_16 Sawah Besar
#      0 / 13
# IDN-Semarang_ADM-4_17 Bulu Lor
#      0 / 5
# IDN-Semarang_ADM-4_18 Kaliwiru
#      0 / 10
# IDN-Semarang_ADM-4_19 Petompon
#      0 / 11
# IDN-Semarang_ADM-4_20 Barusari
#      0 / 5
# IDN-Semarang_ADM-4_21 Gayamsari
#      0 / 19
# IDN-Semarang_ADM-4_22 Rejosari
#      0 / 10
# IDN-Semarang_ADM-4_23 Sarirejo
#      0 / 5
# IDN-Semarang_ADM-4_24 Krobokan
#      0 / 6
# IDN-Semarang_ADM-4_25 Kranggan
# IDN-Semarang_ADM-4_26 Wonotingal
#      0 / 25
# IDN-Semarang_ADM-4_27 Karangrejo
#      0 / 21
# IDN-Semarang_ADM-4_28 Jagalan
#      0 / 2
# IDN-Semarang_ADM-4_29 Panggung Kidul
#      0 / 4
# IDN-Semarang_ADM-4_30 Randusari
#      0 / 19
# IDN-Semarang_ADM-4_31 Kebonagung
#      0 / 3
# IDN-Semarang_ADM-4_32 Bugangan
#      0 / 4
# IDN-Semarang_ADM-4_33 Bendungan
#      0 / 14
# IDN-Semarang_ADM-4_34 Gajah Mungkur
#      0 / 35
# IDN-Semarang_ADM-4_35 Kaligawe
#      0 / 18
# IDN-Semarang_ADM-4_36 Mugassari
#      0 / 11
# IDN-Semarang_ADM-4_37 Tawangmas
#      0 / 20
# IDN-Semarang_ADM-4_38 Karang Ayu
#      0 / 6
# IDN-Semarang_ADM-4_39 Kuningan
#      0 / 16
# IDN-Semarang_ADM-4_40 Mlatiharjo
#      0 / 6
# IDN-Semarang_ADM-4_41 Mlatibaru
#      0 / 8
# IDN-Semarang_ADM-4_42 Pleburan
#      0 / 19
# IDN-Semarang_ADM-4_43 Pandean Lamper
#      0 / 13
# IDN-Semarang_ADM-4_44 Tegalsari
#      0 / 23
# IDN-Semarang_ADM-4_45 Panggung Lor
#      0 / 20
# IDN-Semarang_ADM-4_46 Bangunharjo
# IDN-Semarang_ADM-4_47 Kauman
#      0 / 2
# IDN-Semarang_ADM-4_48 Purwodinatan
#      0 / 1
# IDN-Semarang_ADM-4_49 Tambakrejo
#      0 / 12
# IDN-Semarang_ADM-4_50 Rejomulyo
#      0 / 5
# IDN-Semarang_ADM-4_51 Bandarharjo
#      0 / 55
# IDN-Semarang_ADM-4_52 Wonodri
#      0 / 10
# IDN-Semarang_ADM-4_53 Kembangsari
#      0 / 3
# IDN-Semarang_ADM-4_54 Peterongan
#      0 / 10
# IDN-Semarang_ADM-4_55 Tawangsari
#      0 / 42
# IDN-Semarang_ADM-4_56 Bendan Duwur
#      0 / 12
# IDN-Semarang_ADM-4_57 Tanjungmas
#      0 / 49
# IDN-Semarang_ADM-4_58 Kemijen
#      0 / 13
# IDN-Semarang_ADM-4_59 Bendan Ngisor
#      0 / 9
# IDN-Semarang_ADM-4_60 Lamper Lor
#      0 / 6
# IDN-Semarang_ADM-4_61 Sampangan
#      0 / 7
# IDN-Semarang_ADM-4_62 Lamper Kidul
#      0 / 2
# IDN-Semarang_ADM-4_63 Lamper Tengah
#      0 / 17
# IDN-Semarang_ADM-4_64 Sekayu
#      0 / 12
# IDN-Semarang_ADM-4_65 Miroto
#      0 / 2
# IDN-Semarang_ADM-4_66 Pandansari
#      0 / 5
# IDN-Semarang_ADM-4_67 Candi
#      0 / 14
# IDN-Semarang_ADM-4_68 Sukorejo
#      0 / 11
# IDN-Semarang_ADM-4_69 Bongsari
#      0 / 17
# IDN-Semarang_ADM-4_70 Jomblang
#      0 / 26
# IDN-Semarang_ADM-4_71 Muktiharjo Lor
#      0 / 16
# IDN-Semarang_ADM-4_72 Pekunden
#      0 / 3
# IDN-Semarang_ADM-4_73 Kalicari
#      0 / 20
# IDN-Semarang_ADM-4_74 Gisikdrono
#      0 / 26
# IDN-Semarang_ADM-4_75 Kalibanteng Kidul
#      0 / 8
# IDN-Semarang_ADM-4_76 Kalibanteng Kulon
#      0 / 12
# IDN-Semarang_ADM-4_77 Karanganyar Gunung
#      0 / 21
# IDN-Semarang_ADM-4_78 Terboyo Kulon
#      0 / 24
# IDN-Semarang_ADM-4_79 Terboyo Wetan
#      0 / 15
# IDN-Semarang_ADM-4_80 Ngijo
# IDN-Semarang_ADM-4_81 Kalisegoro
# IDN-Semarang_ADM-4_82 Trimulyo
#      0 / 37
# IDN-Semarang_ADM-4_83 Pedurungan Lor
#      0 / 29
# IDN-Semarang_ADM-4_84 Sekaran
#      0 / 23
# IDN-Semarang_ADM-4_85 Mangunsari
#      0 / 5
# IDN-Semarang_ADM-4_86 Tembalang
#      0 / 24
# IDN-Semarang_ADM-4_87 Gemah
#      0 / 20
# IDN-Semarang_ADM-4_88 Jangli
#      0 / 9
# IDN-Semarang_ADM-4_89 Bulusan
#      0 / 22
# IDN-Semarang_ADM-4_90 Krapyak
#      0 / 11
# IDN-Semarang_ADM-4_91 Pakintelan
# IDN-Semarang_ADM-4_92 Tambak Harjo
#      0 / 40
# IDN-Semarang_ADM-4_93 Bangetayu Kulon
#      0 / 64
# IDN-Semarang_ADM-4_94 Patemon
#      0 / 5
# IDN-Semarang_ADM-4_95 Cangkiran
#      0 / 15
# IDN-Semarang_ADM-4_96 Mangunharjo
#      0 / 28
# IDN-Semarang_ADM-4_97 Polaman
#      0 / 9
# IDN-Semarang_ADM-4_98 Karangkidul
#      0 / 3
# IDN-Semarang_ADM-4_99 Pendrikan Kidul
#      0 / 3
# IDN-Semarang_ADM-4_100 Pendrikan Lor
# IDN-Semarang_ADM-4_101 Kembangarum
#      0 / 30
# IDN-Semarang_ADM-4_102 Palebon
#      0 / 20
# IDN-Semarang_ADM-4_103 Sumurejo
#      0 / 9
# IDN-Semarang_ADM-4_104 Nongkosawit
#      0 / 2
# IDN-Semarang_ADM-4_105 Gebangsari
#      0 / 20
# IDN-Semarang_ADM-4_106 Cepoko
#      0 / 1
# IDN-Semarang_ADM-4_107 Genuksari
#      0 / 61
# IDN-Semarang_ADM-4_108 Gunung Pati
#      0 / 11
# IDN-Semarang_ADM-4_109 Karangmalang
#      0 / 4
# IDN-Semarang_ADM-4_110 Banjardowo
#      0 / 44
# IDN-Semarang_ADM-4_111 Tlogosari Kulon
#      0 / 32
# IDN-Semarang_ADM-4_112 Manyaran
#      0 / 34
# IDN-Semarang_ADM-4_113 Ngemplaksimongan
#      0 / 12
# IDN-Semarang_ADM-4_114 Kudu
#      0 / 17
# IDN-Semarang_ADM-4_115 Pudakpayung
#      0 / 43
# IDN-Semarang_ADM-4_116 Penggaron Lor
#      0 / 7
# IDN-Semarang_ADM-4_117 Karangroto
#      0 / 19
# IDN-Semarang_ADM-4_118 Gedawang
#      0 / 11
# IDN-Semarang_ADM-4_119 Jabungan
#      0 / 5
# IDN-Semarang_ADM-4_120 Tandang
#      0 / 19
# IDN-Semarang_ADM-4_121 Tlogosari Wetan
#      0 / 18
# IDN-Semarang_ADM-4_122 Meteseh
#      0 / 34
# IDN-Semarang_ADM-4_123 Tambangan
#      0 / 12
# IDN-Semarang_ADM-4_124 Jatirejo
#      0 / 2
# IDN-Semarang_ADM-4_125 Mangkang Kulon
#      0 / 41
# IDN-Semarang_ADM-4_126 Sadeng
#      0 / 6
# IDN-Semarang_ADM-4_127 Sembungharjo
#      0 / 17
# IDN-Semarang_ADM-4_128 Bangetayu Wetan
#      0 / 17
# IDN-Semarang_ADM-4_129 Kramas
#      0 / 21
# IDN-Semarang_ADM-4_130 Penggaron Kidul
#      0 / 20
# IDN-Semarang_ADM-4_131 Bubakan
#      0 / 20
# IDN-Semarang_ADM-4_132 Sendangguwo
#      0 / 20
# IDN-Semarang_ADM-4_133 Mangunharjo
#      0 / 26
# IDN-Semarang_ADM-4_134 Mangkang Wetan
#      0 / 20
# IDN-Semarang_ADM-4_135 Ngaliyan
#      0 / 72
# IDN-Semarang_ADM-4_136 Purwoyoso
#      0 / 35
# IDN-Semarang_ADM-4_137 Bambankerep
#      0 / 45
# IDN-Semarang_ADM-4_138 Tambakaji
#      0 / 34
# IDN-Semarang_ADM-4_139 Randugarut
#      0 / 42
# IDN-Semarang_ADM-4_140 Pedurungan Tengah
#      0 / 38
# IDN-Semarang_ADM-4_141 Banyumanik
#      0 / 30
# IDN-Semarang_ADM-4_142 Tlogomulyo
#      0 / 27
# IDN-Semarang_ADM-4_143 Jatisari
#      0 / 8
# IDN-Semarang_ADM-4_144 Purwosari
#      0 / 12
# IDN-Semarang_ADM-4_145 Plamongan Sari
#      0 / 31
# IDN-Semarang_ADM-4_146 Padangsari
#      0 / 16
# IDN-Semarang_ADM-4_147 Bringin
#      0 / 27
# IDN-Semarang_ADM-4_148 Kandri
#      0 / 2
# IDN-Semarang_ADM-4_149 Plalangan
#      0 / 5
# IDN-Semarang_ADM-4_150 Pongangan
#      0 / 1
# IDN-Semarang_ADM-4_151 Pedalangan
#      0 / 62
# IDN-Semarang_ADM-4_152 Sendangmulyo
#      0 / 56
# IDN-Semarang_ADM-4_153 Karanganyar
#      0 / 43
# IDN-Semarang_ADM-4_154 Sambiroto
#      0 / 24
# IDN-Semarang_ADM-4_155 Tugurejo
#      0 / 60
# IDN-Semarang_ADM-4_156 Kedungmundu
#      0 / 33
# IDN-Semarang_ADM-4_157 Jerakah
#      0 / 21
# IDN-Semarang_ADM-4_158 Wonolopo
#      0 / 8
# IDN-Semarang_ADM-4_159 Mijen
#      0 / 7
# IDN-Semarang_ADM-4_160 Pedurungan Kidul
#      0 / 27
# IDN-Semarang_ADM-4_161 Muktiharjo Kidul
#      0 / 39
# IDN-Semarang_ADM-4_162 Jatibarang
#      0 / 17
# IDN-Semarang_ADM-4_163 Ngadirgo
#      0 / 10
# IDN-Semarang_ADM-4_164 Wonoplumbon
#      0 / 1
# IDN-Semarang_ADM-4_165 Wates
#      0 / 10
# IDN-Semarang_ADM-4_166 Podorejo
#      0 / 8
# IDN-Semarang_ADM-4_167 Rowosari
#      0 / 20
# IDN-Semarang_ADM-4_168 Gondoriyo
#      0 / 11
# IDN-Semarang_ADM-4_169 Wonosari
#      0 / 42
# IDN-Semarang_ADM-4_170 Kalipancur
#      0 / 47
# IDN-Semarang_ADM-4_171 Pesantren
#      0 / 22
# IDN-Semarang_ADM-4_172 Kedungpane
#      0 / 11
# IDN-Semarang_ADM-4_173 Srondol Wetan
#      0 / 47
# IDN-Semarang_ADM-4_174 Srondol Kulon
#      0 / 29
# IDN-Semarang_ADM-4_175 Tinjomoyo
#      0 / 14
# IDN-Semarang_ADM-4_176 Sumurboto
#      0 / 45
# IDN-Semarang_ADM-4_177 Ngesrep
#      0 / 41
# IDN-Balikpapan_ADM-4-union_1 IDN-Balikpapan
#      0 / 1211
#      1000 / 1211
# IDN-Balikpapan_ADM-4_1 Kelurahan Manggar Baru
#      0 / 33
# IDN-Balikpapan_ADM-4_2 Kelurahan Baru Ulu
#      0 / 20
# IDN-Balikpapan_ADM-4_3 Kelurahan Karang Jati
#      0 / 73
# IDN-Balikpapan_ADM-4_4 Kelurahan Prapatan
#      0 / 42
# IDN-Balikpapan_ADM-4_5 Kelurahan Manggar
#      0 / 111
# IDN-Balikpapan_ADM-4_6 Kelurahan Muara Rapak
#      0 / 44
# IDN-Balikpapan_ADM-4_7 Kelurahan Gunung Sari Ulu
#      0 / 19
# IDN-Balikpapan_ADM-4_8 Kelurahan Gunung Sari Ilir
#      0 / 22
# IDN-Balikpapan_ADM-4_9 Kelurahan Mekar Sari
#      0 / 16
# IDN-Balikpapan_ADM-4_10 Kelurahan Karang Rejo
#      0 / 19
# IDN-Balikpapan_ADM-4_11 Kelurahan Sumber Rejo
#      0 / 27
# IDN-Balikpapan_ADM-4_12 Kelurahan Klandasan Ulu
#      0 / 33
# IDN-Balikpapan_ADM-4_13 Kelurahan Tlaga Sari
#      0 / 30
# IDN-Balikpapan_ADM-4_14 Kelurahan Klandasan Ilir
#      0 / 25
# IDN-Balikpapan_ADM-4_15 Kelurahan Damai
#      0 / 103
# IDN-Balikpapan_ADM-4_16 Kelurahan Gunung Bahagia
#      0 / 101
# IDN-Balikpapan_ADM-4_17 Kelurahan Sepinggan
#      0 / 156
# IDN-Balikpapan_ADM-4_18 Kelurahan Margo Mulyo
#      0 / 35
# IDN-Balikpapan_ADM-4_19 Kelurahan Marga Sari
#      0 / 6
# IDN-Balikpapan_ADM-4_20 Kelurahan Baru Ilir
#      0 / 16
# IDN-Balikpapan_ADM-4_21 Kelurahan Baru Tengan
#      0 / 19
# IDN-Balikpapan_ADM-4_22 Kelurahan Kariangau
#      0 / 84
# IDN-Balikpapan_ADM-4_23 Kelurahan Batu Ampar
#      0 / 139
# IDN-Balikpapan_ADM-4_24 Kelurahan Gunung Samarinda
#      0 / 109
# IDN-Balikpapan_ADM-4_25 Kelurahan Karang Joang
#      0 / 34
# IDN-Balikpapan_ADM-4_26 Kelurahan Lamaru
#      0 / 23
# IDN-Balikpapan_ADM-4_27 Kelurahan Teririp
#      0 / 8
# IDN-Palembang_ADM-2-union_1 IDN-Palembang
#      0 / 3119
#      1000 / 3119
#      2000 / 3119
#      3000 / 3119
# IDN-Palembang_ADM-3_1 Plaju
#      0 / 158
# IDN-Palembang_ADM-3_2 Seberang Ulu II
#      0 / 124
# IDN-Palembang_ADM-3_3 Seberang Ulu I
#      0 / 221
# IDN-Palembang_ADM-3_4 Alang-Alang Lebar
#      0 / 187
# IDN-Palembang_ADM-3_5 Sukarame
#      0 / 501
# IDN-Palembang_ADM-3_6 Sako
#      0 / 195
# IDN-Palembang_ADM-3_7 Sematang Borang
#      0 / 22
# IDN-Palembang_ADM-3_8 Kalidoni
#      0 / 292
# IDN-Palembang_ADM-3_9 Kemuning
#      0 / 141
# IDN-Palembang_ADM-3_10 Ilir Timur II
#      0 / 206
# IDN-Palembang_ADM-3_11 Ilir Timur I
#      0 / 54
# IDN-Palembang_ADM-3_12 Bukit Kecil
#      0 / 56
# IDN-Palembang_ADM-3_13 Ilir Barat II
#      0 / 73
# IDN-Palembang_ADM-3_14 Ilir Barat I
#      0 / 389
# IDN-Palembang_ADM-3_15 Gandus
#      0 / 174
# IDN-Palembang_ADM-3_16 Kertapati
#      0 / 392
# CPU times: user 6h 32min 38s, sys: 21min 30s, total: 6h 54min 9s
# Wall time: 7h 2min 47s

# %%
# read indicator table
cities_indicators = pd.read_csv('https://cities-urbanshift.s3.eu-west-3.amazonaws.com/indicators/cities_indicators_v2.csv')

# %%
cities_indicators
# Out:
#                          geo_id    geo_level                    geo_name  \
# 0     ARG-Mendoza_ADM-3-union_1  ADM-3-union                 ARG-Mendoza
# 1           ARG-Mendoza_ADM-3_1        ADM-3      Distrito Las Barrancas
# 2           ARG-Mendoza_ADM-3_2        ADM-3          Distrito San Roque
# 3           ARG-Mendoza_ADM-3_3        ADM-3  Distrito Fray Luis Beltrán
# 4           ARG-Mendoza_ADM-3_4        ADM-3    Distrito Rodeo del Medio
# ...                         ...          ...                         ...
# 1935     IDN-Palembang_ADM-3_12        ADM-3                 Bukit Kecil
# 1936     IDN-Palembang_ADM-3_13        ADM-3               Ilir Barat II
# 1937     IDN-Palembang_ADM-3_14        ADM-3                Ilir Barat I
# 1938     IDN-Palembang_ADM-3_15        ADM-3                      Gandus
# 1939     IDN-Palembang_ADM-3_16        ADM-3                   Kertapati
#
#      geo_parent_name
# 0        ARG-Mendoza
# 1        ARG-Mendoza
# 2        ARG-Mendoza
# 3        ARG-Mendoza
# 4        ARG-Mendoza
# ...              ...
# 1935   IDN-Palembang
# 1936   IDN-Palembang
# 1937   IDN-Palembang
# 1938   IDN-Palembang
# 1939   IDN-Palembang
#
# [1940 rows x 4 columns]

# %%
sibc2_df = pd.read_csv('outputs.tsv', sep='\t')

# %%
sibc2_df = sibc2_df.drop('geo_name', axis=1).rename({'SICB-2':'SICB_2_habitat_connectivity'}, axis=1)

# %%
sibc2_df.head()
# Out:
#                       geo_id  SICB_2_habitat_connectivity
# 0  ARG-Mendoza_ADM-3-union_1                     0.654064
# 1        ARG-Mendoza_ADM-3_1                     0.051461
# 2        ARG-Mendoza_ADM-3_2                     0.910816
# 3        ARG-Mendoza_ADM-3_3                     0.979369
# 4        ARG-Mendoza_ADM-3_4                     0.958122

# %%
cities_indicators_merged = cities_indicators.merge(sibc2_df[["geo_id", 'SICB_2_habitat_connectivity']], 
                                                     on='geo_id', 
                                                     how='left')

# %%
cities_indicators_merged.head()
# Out:
#                       geo_id    geo_level                    geo_name  \
# 0  ARG-Mendoza_ADM-3-union_1  ADM-3-union                 ARG-Mendoza
# 1        ARG-Mendoza_ADM-3_1        ADM-3      Distrito Las Barrancas
# 2        ARG-Mendoza_ADM-3_2        ADM-3          Distrito San Roque
# 3        ARG-Mendoza_ADM-3_3        ADM-3  Distrito Fray Luis Beltrán
# 4        ARG-Mendoza_ADM-3_4        ADM-3    Distrito Rodeo del Medio
#
#   geo_parent_name  SICB_2_habitat_connectivity
# 0     ARG-Mendoza                     0.654064
# 1     ARG-Mendoza                     0.051461
# 2     ARG-Mendoza                     0.910816
# 3     ARG-Mendoza                     0.979369
# 4     ARG-Mendoza                     0.958122

# %% [markdown]
# ## Upload in aws s3

# %%
# connect to s3

import boto3

aws_key = "AKIA4GK7IHHC5RCMFKEG"
aws_secret = "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"

s3 = boto3.resource(
    service_name='s3',
    aws_access_key_id=aws_key,
    aws_secret_access_key=aws_secret
)

# %%
# upload to aws
key_data = 'indicators/cities_indicators_v2_test-ted.csv'
bucket_name = 'cities-urbanshift' 
cities_indicators_merged.to_csv(
    f"s3://{bucket_name}/{key_data}",
    index=False,
    storage_options={
        "key": aws_key,
        "secret": aws_secret
    },
)

# %%
# make it public
object_acl = s3.ObjectAcl(bucket_name,key_data)
response = object_acl.put(ACL='public-read')

# %%
https://cities-urbanshift.s3.eu-west-3.amazonaws.com/indicators/cities_indicators_v2_test-ted.csv
