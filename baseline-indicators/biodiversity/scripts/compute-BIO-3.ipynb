# %%
import sys
# !{sys.executable} -m pip install pip earthengine-api
# !{sys.executable} -m pip install pip geemap
# !{sys.executable} -m pip install --extra-index-url https://artifactory.vgt.vito.be/api/pypi/python-packages/simple terracatalogueclient
# !{sys.executable} -m pip install pip rasterstats
# Out:
# Requirement already satisfied: pip in /srv/conda/envs/notebook/lib/python3.10/site-packages (22.2.2)
# Requirement already satisfied: earthengine-api in /srv/conda/envs/notebook/lib/python3.10/site-packages (0.1.332)
# Requirement already satisfied: future in /srv/conda/envs/notebook/lib/python3.10/site-packages (from earthengine-api) (0.18.2)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from earthengine-api) (0.1.0)
# Requirement already satisfied: requests in /srv/conda/envs/notebook/lib/python3.10/site-packages (from earthengine-api) (2.28.1)
# Requirement already satisfied: six in /srv/conda/envs/notebook/lib/python3.10/site-packages (from earthengine-api) (1.16.0)
# Requirement already satisfied: google-cloud-storage in /srv/conda/envs/notebook/lib/python3.10/site-packages (from earthengine-api) (2.5.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from earthengine-api) (0.21.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from earthengine-api) (2.66.0)
# Requirement already satisfied: google-auth>=1.4.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from earthengine-api) (2.11.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-api-python-client>=1.12.1->earthengine-api) (2.10.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-api-python-client>=1.12.1->earthengine-api) (4.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-auth>=1.4.1->earthengine-api) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-auth>=1.4.1->earthengine-api) (0.2.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-auth>=1.4.1->earthengine-api) (4.7.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from httplib2<1dev,>=0.9.2->earthengine-api) (3.0.9)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-cloud-storage->earthengine-api) (2.3.2)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-cloud-storage->earthengine-api) (2.3.3)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests->earthengine-api) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests->earthengine-api) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests->earthengine-api) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests->earthengine-api) (2.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (1.56.4)
# Requirement already satisfied: protobuf<5.0.0dev,>=3.20.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (4.21.5)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-resumable-media>=2.3.2->google-cloud-storage->earthengine-api) (1.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api) (0.4.8)
# Requirement already satisfied: cffi>=1.0.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-crc32c<2.0dev,>=1.0->google-resumable-media>=2.3.2->google-cloud-storage->earthengine-api) (1.15.1)
# Requirement already satisfied: pycparser in /srv/conda/envs/notebook/lib/python3.10/site-packages (from cffi>=1.0.0->google-crc32c<2.0dev,>=1.0->google-resumable-media>=2.3.2->google-cloud-storage->earthengine-api) (2.21)
# Requirement already satisfied: pip in /srv/conda/envs/notebook/lib/python3.10/site-packages (22.2.2)
# Requirement already satisfied: geemap in /srv/conda/envs/notebook/lib/python3.10/site-packages (0.17.3)
# Requirement already satisfied: scooby in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geemap) (0.6.0)
# Requirement already satisfied: geeadd>=0.5.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geemap) (0.5.6)
# Requirement already satisfied: pyshp>=2.1.3 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geemap) (2.3.1)
# Requirement already satisfied: xyzservices in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geemap) (2022.6.0)
# Requirement already satisfied: ipyevents in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geemap) (2.0.1)
# Requirement already satisfied: ipytree in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geemap) (0.2.2)
# Requirement already satisfied: geocoder in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geemap) (1.38.1)
# Requirement already satisfied: pycrs in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geemap) (1.0.2)
# Requirement already satisfied: sankee>=0.1.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geemap) (0.2.0)
# Requirement already satisfied: ee-extra>=0.0.10 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geemap) (0.0.14)
# Requirement already satisfied: whiteboxgui>=0.6.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geemap) (0.7.0)
# Requirement already satisfied: colour in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geemap) (0.1.5)
# Requirement already satisfied: ffmpeg-python in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geemap) (0.2.0)
# Requirement already satisfied: pillow in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geemap) (9.2.0)
# Requirement already satisfied: ipyleaflet>=0.17.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geemap) (0.17.1)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geemap) (0.6.0)
# Requirement already satisfied: matplotlib in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geemap) (3.5.3)
# Requirement already satisfied: numpy in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geemap) (1.22.4)
# Requirement already satisfied: jupyterlab>=3 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geemap) (3.4.4)
# Requirement already satisfied: python-box in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geemap) (6.0.2)
# Requirement already satisfied: bqplot in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geemap) (0.12.36)
# Requirement already satisfied: gdown in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geemap) (4.5.1)
# Requirement already satisfied: geojson in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geemap) (2.5.0)
# Requirement already satisfied: pandas in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geemap) (1.4.4)
# Requirement already satisfied: folium>=0.11.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geemap) (0.12.1.post1)
# Requirement already satisfied: earthengine-api>=0.1.304 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geemap) (0.1.332)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from earthengine-api>=0.1.304->geemap) (0.1.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from earthengine-api>=0.1.304->geemap) (2.66.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from earthengine-api>=0.1.304->geemap) (0.21.0)
# Requirement already satisfied: google-auth>=1.4.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from earthengine-api>=0.1.304->geemap) (2.11.0)
# Requirement already satisfied: requests in /srv/conda/envs/notebook/lib/python3.10/site-packages (from earthengine-api>=0.1.304->geemap) (2.28.1)
# Requirement already satisfied: future in /srv/conda/envs/notebook/lib/python3.10/site-packages (from earthengine-api>=0.1.304->geemap) (0.18.2)
# Requirement already satisfied: google-cloud-storage in /srv/conda/envs/notebook/lib/python3.10/site-packages (from earthengine-api>=0.1.304->geemap) (2.5.0)
# Requirement already satisfied: six in /srv/conda/envs/notebook/lib/python3.10/site-packages (from earthengine-api>=0.1.304->geemap) (1.16.0)
# Requirement already satisfied: branca>=0.3.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from folium>=0.11.0->geemap) (0.5.0)
# Requirement already satisfied: jinja2>=2.9 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from folium>=0.11.0->geemap) (3.1.2)
# Requirement already satisfied: logzero>=1.5.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geeadd>=0.5.1->geemap) (1.7.0)
# Requirement already satisfied: beautifulsoup4>=4.9.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geeadd>=0.5.1->geemap) (4.11.1)
# Requirement already satisfied: ipywidgets in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipyfilechooser>=0.6.0->geemap) (7.7.1)
# Requirement already satisfied: traittypes<3,>=0.2.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipyleaflet>=0.17.0->geemap) (0.2.1)
# Requirement already satisfied: ipython in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jupyterlab>=3->geemap) (8.5.0)
# Requirement already satisfied: tornado>=6.1.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jupyterlab>=3->geemap) (6.1)
# Requirement already satisfied: jupyter-server~=1.16 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jupyterlab>=3->geemap) (1.18.1)
# Requirement already satisfied: jupyter-core in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jupyterlab>=3->geemap) (4.11.1)
# Requirement already satisfied: nbclassic in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jupyterlab>=3->geemap) (0.4.3)
# Requirement already satisfied: notebook<7 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jupyterlab>=3->geemap) (6.4.12)
# Requirement already satisfied: jupyterlab-server~=2.10 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jupyterlab>=3->geemap) (2.15.1)
# Requirement already satisfied: packaging in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jupyterlab>=3->geemap) (21.3)
# Requirement already satisfied: plotly>=5.2.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from sankee>=0.1.0->geemap) (5.11.0)
# Requirement already satisfied: whitebox in /srv/conda/envs/notebook/lib/python3.10/site-packages (from whiteboxgui>=0.6.0->geemap) (2.1.4)
# Requirement already satisfied: traitlets>=4.3.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from bqplot->geemap) (5.4.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas->geemap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas->geemap) (2022.2.1)
# Requirement already satisfied: tqdm in /srv/conda/envs/notebook/lib/python3.10/site-packages (from gdown->geemap) (4.64.1)
# Requirement already satisfied: filelock in /srv/conda/envs/notebook/lib/python3.10/site-packages (from gdown->geemap) (3.8.0)
# Requirement already satisfied: click in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geocoder->geemap) (8.0.4)
# Requirement already satisfied: ratelim in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geocoder->geemap) (0.1.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib->geemap) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib->geemap) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib->geemap) (4.37.2)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib->geemap) (0.11.0)
# Requirement already satisfied: soupsieve>1.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from beautifulsoup4>=4.9.0->geeadd>=0.5.1->geemap) (2.3.2.post1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-api-python-client>=1.12.1->earthengine-api>=0.1.304->geemap) (4.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-api-python-client>=1.12.1->earthengine-api>=0.1.304->geemap) (2.10.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.304->geemap) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.304->geemap) (0.2.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.304->geemap) (4.7.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.1.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.15.3)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.6.1)
# Requirement already satisfied: decorator in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipython->jupyterlab>=3->geemap) (5.1.1)
# Requirement already satisfied: matplotlib-inline in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipython->jupyterlab>=3->geemap) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipython->jupyterlab>=3->geemap) (3.0.31)
# Requirement already satisfied: stack-data in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipython->jupyterlab>=3->geemap) (0.5.0)
# Requirement already satisfied: pickleshare in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipython->jupyterlab>=3->geemap) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipython->jupyterlab>=3->geemap) (0.18.1)
# Requirement already satisfied: backcall in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipython->jupyterlab>=3->geemap) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipython->jupyterlab>=3->geemap) (4.8.0)
# Requirement already satisfied: pygments>=2.4.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipython->jupyterlab>=3->geemap) (2.13.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jinja2>=2.9->folium>=0.11.0->geemap) (2.1.1)
# Requirement already satisfied: nbformat>=5.2.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (5.5.0)
# Requirement already satisfied: nbconvert>=6.4.4 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (6.5.3)
# Requirement already satisfied: anyio<4,>=3.1.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (3.6.1)
# Requirement already satisfied: terminado>=0.8.3 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (0.15.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (7.3.4)
# Requirement already satisfied: websocket-client in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (1.4.1)
# Requirement already satisfied: prometheus-client in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (0.14.1)
# Requirement already satisfied: argon2-cffi in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (21.3.0)
# Requirement already satisfied: Send2Trash in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (1.8.0)
# Requirement already satisfied: pyzmq>=17 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (24.0.0)
# Requirement already satisfied: json5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jupyterlab-server~=2.10->jupyterlab>=3->geemap) (0.9.5)
# Requirement already satisfied: jsonschema>=3.0.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jupyterlab-server~=2.10->jupyterlab>=3->geemap) (4.16.0)
# Requirement already satisfied: babel in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jupyterlab-server~=2.10->jupyterlab>=3->geemap) (2.10.3)
# Requirement already satisfied: nest-asyncio>=1.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from notebook<7->jupyterlab>=3->geemap) (1.5.5)
# Requirement already satisfied: tenacity>=6.2.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from plotly>=5.2.2->sankee>=0.1.0->geemap) (8.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests->earthengine-api>=0.1.304->geemap) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests->earthengine-api>=0.1.304->geemap) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests->earthengine-api>=0.1.304->geemap) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests->earthengine-api>=0.1.304->geemap) (3.3)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-cloud-storage->earthengine-api>=0.1.304->geemap) (2.3.3)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-cloud-storage->earthengine-api>=0.1.304->geemap) (2.3.2)
# Requirement already satisfied: notebook-shim>=0.1.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from nbclassic->jupyterlab>=3->geemap) (0.1.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests->earthengine-api>=0.1.304->geemap) (1.7.1)
# Requirement already satisfied: sniffio>=1.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.16->jupyterlab>=3->geemap) (1.3.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=0.1.304->geemap) (1.56.4)
# Requirement already satisfied: protobuf<5.0.0dev,>=3.20.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=0.1.304->geemap) (4.21.5)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-resumable-media>=2.3.2->google-cloud-storage->earthengine-api>=0.1.304->geemap) (1.1.2)
# Requirement already satisfied: psutil in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.9.2)
# Requirement already satisfied: debugpy>=1.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.6.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jedi>=0.16->ipython->jupyterlab>=3->geemap) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab>=3->geemap) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab>=3->geemap) (22.1.0)
# Requirement already satisfied: entrypoints in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jupyter-client>=6.1.12->jupyter-server~=1.16->jupyterlab>=3->geemap) (0.4)
# Requirement already satisfied: nbclient>=0.5.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (0.5.13)
# Requirement already satisfied: bleach in /srv/conda/envs/notebook/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (5.0.1)
# Requirement already satisfied: lxml in /srv/conda/envs/notebook/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (4.9.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (1.5.0)
# Requirement already satisfied: defusedxml in /srv/conda/envs/notebook/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /srv/conda/envs/notebook/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (0.2.2)
# Requirement already satisfied: tinycss2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (1.1.1)
# Requirement already satisfied: fastjsonschema in /srv/conda/envs/notebook/lib/python3.10/site-packages (from nbformat>=5.2.0->jupyter-server~=1.16->jupyterlab>=3->geemap) (2.16.1)
# Requirement already satisfied: ptyprocess>=0.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pexpect>4.3->ipython->jupyterlab>=3->geemap) (0.7.0)
# Requirement already satisfied: wcwidth in /srv/conda/envs/notebook/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython->jupyterlab>=3->geemap) (0.2.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=0.1.304->geemap) (0.4.8)
# Requirement already satisfied: argon2-cffi-bindings in /srv/conda/envs/notebook/lib/python3.10/site-packages (from argon2-cffi->jupyter-server~=1.16->jupyterlab>=3->geemap) (21.2.0)
# Requirement already satisfied: asttokens in /srv/conda/envs/notebook/lib/python3.10/site-packages (from stack-data->ipython->jupyterlab>=3->geemap) (2.0.8)
# Requirement already satisfied: executing in /srv/conda/envs/notebook/lib/python3.10/site-packages (from stack-data->ipython->jupyterlab>=3->geemap) (1.0.0)
# Requirement already satisfied: pure-eval in /srv/conda/envs/notebook/lib/python3.10/site-packages (from stack-data->ipython->jupyterlab>=3->geemap) (0.2.2)
# Requirement already satisfied: cffi>=1.0.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-crc32c<2.0dev,>=1.0->google-resumable-media>=2.3.2->google-cloud-storage->earthengine-api>=0.1.304->geemap) (1.15.1)
# Requirement already satisfied: webencodings in /srv/conda/envs/notebook/lib/python3.10/site-packages (from bleach->nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (0.5.1)
# Requirement already satisfied: pycparser in /srv/conda/envs/notebook/lib/python3.10/site-packages (from cffi>=1.0.0->google-crc32c<2.0dev,>=1.0->google-resumable-media>=2.3.2->google-cloud-storage->earthengine-api>=0.1.304->geemap) (2.21)
# Looking in indexes: https://pypi.org/simple, https://artifactory.vgt.vito.be/api/pypi/python-packages/simple
# Collecting terracatalogueclient
#   Using cached https://artifactory.vgt.vito.be/api/pypi/python-packages/terracatalogueclient/0.1.14/terracatalogueclient-0.1.14-py3-none-any.whl (12 kB)
# Requirement already satisfied: boto3 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from terracatalogueclient) (1.24.59)
# Requirement already satisfied: requests in /srv/conda/envs/notebook/lib/python3.10/site-packages (from terracatalogueclient) (2.28.1)
# Requirement already satisfied: shapely in /srv/conda/envs/notebook/lib/python3.10/site-packages (from terracatalogueclient) (1.8.4)
# Collecting requests-auth>=5.3.0
#   Using cached https://artifactory.vgt.vito.be/api/pypi/python-packages/packages/packages/60/af/da90802d91cbc45bdc160e9dcc70a07cbb581d748549edc3d42d25e04c8f/requests_auth-6.0.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: humanfriendly in /srv/conda/envs/notebook/lib/python3.10/site-packages (from terracatalogueclient) (10.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests->terracatalogueclient) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests->terracatalogueclient) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests->terracatalogueclient) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests->terracatalogueclient) (1.26.11)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from boto3->terracatalogueclient) (0.6.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from boto3->terracatalogueclient) (1.0.1)
# Requirement already satisfied: botocore<1.28.0,>=1.27.59 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from boto3->terracatalogueclient) (1.27.59)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from botocore<1.28.0,>=1.27.59->boto3->terracatalogueclient) (2.8.2)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.28.0,>=1.27.59->boto3->terracatalogueclient) (1.16.0)
# Installing collected packages: requests-auth, terracatalogueclient
# Successfully installed requests-auth-6.0.0 terracatalogueclient-0.1.14
# Requirement already satisfied: pip in /srv/conda/envs/notebook/lib/python3.10/site-packages (22.2.2)
# Collecting rasterstats
#   Using cached rasterstats-0.17.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: cligj>=0.4 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterstats) (0.7.2)
# Requirement already satisfied: shapely in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterstats) (1.8.4)
# Collecting simplejson
#   Using cached simplejson-3.18.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (143 kB)
# Requirement already satisfied: fiona in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterstats) (1.8.21)
# Requirement already satisfied: rasterio>=1.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterstats) (1.3.2)
# Requirement already satisfied: numpy>=1.9 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterstats) (1.22.4)
# Requirement already satisfied: affine<3.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterstats) (2.3.1)
# Requirement already satisfied: click>=4.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from cligj>=0.4->rasterstats) (8.0.4)
# Requirement already satisfied: click-plugins in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterio>=1.0->rasterstats) (1.1.1)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterio>=1.0->rasterstats) (65.3.0)
# Requirement already satisfied: snuggs>=1.4.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterio>=1.0->rasterstats) (1.4.7)
# Requirement already satisfied: attrs in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterio>=1.0->rasterstats) (22.1.0)
# Requirement already satisfied: certifi in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterio>=1.0->rasterstats) (2022.9.14)
# Requirement already satisfied: munch in /srv/conda/envs/notebook/lib/python3.10/site-packages (from fiona->rasterstats) (2.5.0)
# Requirement already satisfied: six>=1.7 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from fiona->rasterstats) (1.16.0)
# Requirement already satisfied: pyparsing>=2.1.6 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from snuggs>=1.4.1->rasterio>=1.0->rasterstats) (3.0.9)
# Installing collected packages: simplejson, rasterstats
# Successfully installed rasterstats-0.17.0 simplejson-3.18.0

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
import os, requests, json, geojson
import random, scipy
from collections import defaultdict
from scipy.optimize import curve_fit
import numpy as np
from shapely.geometry import Point, Polygon, MultiPolygon, shape
from shapely.ops import unary_union
import rasterio
from rasterio.features import shapes
import shapely
from shapely.ops import transform
from rasterio.merge import merge as rmerge
import rasterio.mask
from rasterstats import point_query
import pandas as pd
import geopandas as gpd
import ee
import geemap
from terracatalogueclient import Catalogue as Terracat

# %%
service_account = 'climate-hazard-demo@data-portal-adaptation.iam.gserviceaccount.com'
credentials = ee.ServiceAccountCredentials(service_account, 'google_cred.json')
ee.Initialize(credentials)

# %%
OUTPUT_FILENAME = 'BIO-3dec.csv'

# %%
API_URL = 'https://api.gbif.org/v1/occurrence/search/'
DATASETKEY = '50c9509d-22c7-4a22-a47d-8c48425ef4a7'  # iNaturalist research-grade observations
#TAXONKEYS = {'Arthropoda': '54', 'Aves': '212', 'Tracheophyta': '7707728'}
TAXON = 'Aves'
TAXON_KEY = '212'
STARTYEAR = '2016'
ENDYEAR = '2021'
LIMIT = 300

NUM_CURVEFITS = 200

# %%
worldcover_catalogue = Terracat().authenticate() 
terracat = worldcover_catalogue.authenticate_non_interactive('tedwongwri', 'WRIpass12!')

# %%
# define directory
out_dir = os.getcwd()
aws_s3_dir = "https://cities-urbanshift.s3.eu-west-3.amazonaws.com/data"

# %%
# get list of urbanshift cities
boundary_georef = pd.read_csv('https://cities-urbanshift.s3.eu-west-3.amazonaws.com/data/boundaries/v_0/boundary_georef.csv')

# remove cities without tree cover data availability
#tml_not_available_cities = ['BRA-Salvador','MEX-Monterrey']
tml_not_available_cities = []
boundary_georef = boundary_georef[~boundary_georef['geo_name'].isin(tml_not_available_cities)].reset_index(drop=True)
boundary_georef
# Out:
#              geo_name   level aoi_boundary_name units_boundary_name  \
# 0         ARG-Mendoza  region         ADM3union                ADM3
# 1   ARG-Mar_del_Plata    city              ADM3                ADM4
# 2   ARG-Mar_del_Plata  region              ADM2                 NaN
# 3         ARG-Ushuaia    city              ADM4                ADM5
# 4         ARG-Ushuaia  region              ADM3                 NaN
# 5           ARG-Salta  region         ADM2union                ADM3
# 6    ARG-Buenos_Aires  region         ADM2union                ADM2
# 7        BRA-Teresina    city         ADM4union                ADM4
# 8        BRA-Teresina  region         ADM2union                ADM2
# 9   BRA-Florianopolis    city         ADM4union                ADM4
# 10  BRA-Florianopolis  region         ADM2union                ADM2
# 11          BRA-Belem    city         ADM4union                ADM4
# 12          BRA-Belem  region         ADM2union                ADM2
# 13       CRI-San_Jose  region         ADM2union                ADM2
# 14         RWA-Kigali    city         ADM4union                ADM4
# 15       SLE-Freetown    city     ADM4cityunion            ADM4city
# 16       SLE-Freetown  region   ADM4regionunion          ADM4region
# 17      MAR-Marrakech     NaN              ADM2                ADM5
# 18        IND-Chennai  region         ADM4union                ADM4
# 19        IND-Chennai    city         ADM6union                ADM6
# 20           IND-Pune  region         ADM4union                ADM4
# 21          IND-Surat  region         ADM4union                ADM4
# 22        CHN-Chengdu     NaN         ADM3union                ADM3
# 23      CHN-Chongqing     NaN              ADM1                ADM3
# 24         CHN-Ningbo     NaN         ADM3union                ADM3
# 25        IDN-Jakarta     NaN         ADM4union                ADM4
# 26         IDN-Bitung     NaN              ADM2                ADM3
# 27       IDN-Semarang     NaN              ADM1                ADM4
# 28     IDN-Balikpapan     NaN         ADM4union                ADM4
# 29      IDN-Palembang     NaN              ADM2                ADM3
#
#                city_name  country_name country_code continent
# 0                Mendoza     Argentina          ARG   America
# 1     Mar del Plata city     Argentina          ARG   America
# 2   Mar del Plata region     Argentina          ARG   America
# 3           Ushuaia city     Argentina          ARG   America
# 4         Ushuaia region     Argentina          ARG   America
# 5                  Salta     Argentina          ARG   America
# 6           Buenos Aires     Argentina          ARG   America
# 7          Teresina city        Brazil          BRA   America
# 8        Teresina region        Brazil          BRA   America
# 9          Florianopolis        Brazil          BRA   America
# 10         Florianopolis        Brazil          BRA   America
# 11            Belem city        Brazil          BRA   America
# 12          Belem region        Brazil          BRA   America
# 13              San Jose    Costa Rica          CRI   America
# 14                Kigali        Rwanda          RWA    Africa
# 15         Freetown city  Sierra Leone          SLE    Africa
# 16       Freetown region  Sierra Leone          SLE    Africa
# 17             Marrakech       Morocco          MAR    Africa
# 18        Chennai region         India          IND      Asia
# 19          Chennai city         India          IND      Asia
# 20                 Pune          India          IND      Asia
# 21                 Surat         India          IND      Asia
# 22               Chengdu         China          CHN      Asia
# 23             Chongqing         China          CHN      Asia
# 24                Ningbo         China          CHN      Asia
# 25               Jakarta     Indonesia          IDN      Asia
# 26                Bitung     Indonesia          IDN      Asia
# 27              Semarang     Indonesia          IDN      Asia
# 28            Balikpapan     Indonesia          IDN      Asia
# 29             Palembang     Indonesia          IDN      Asia

# %%
def boundingbox_wkt(p):
    # Returns WKT for bounding box.
    # Necessary because GBIF API won't accept complex polygons.
    minx, miny, maxx, maxy = p.bounds
    return 'POLYGON (({0} {3}, {0} {2}, {1} {2}, {0} {3}))'.format(str(minx), str(maxx), str(miny), str(maxy))

# %%
def classify_builtup(r):
    r[r != 50] = 0
    r[r == 50] = 1    # built up
    return r

# %%
# This function clips and masks raster
# Adapted from https://gis.stackexchange.com/a/387772

def mask_raster_with_geometry(raster, transform, shapes, **kwargs):
    """Wrapper for rasterio.mask.mask to allow for in-memory processing.

    Docs: https://rasterio.readthedocs.io/en/latest/api/rasterio.mask.html

    Args:
        raster (numpy.ndarray): raster to be masked with dim: [H, W]
        transform (affine.Affine): the transform of the raster
        shapes, **kwargs: passed to rasterio.mask.mask

    Returns:
        masked: numpy.ndarray or numpy.ma.MaskedArray with dim: [H, W], and new affine transform
    """
    with rasterio.io.MemoryFile() as memfile:
        with memfile.open(
            driver='GTiff',
            height=raster.shape[0],
            width=raster.shape[1],
            count=1,
            dtype=raster.dtype,
            transform=transform,
        ) as dataset:
            dataset.write(raster, 1)
        with memfile.open() as dataset:
            output, new_transform = rasterio.mask.mask(dataset, shapes, **kwargs)
    return output.squeeze(0), new_transform

# %%
def get_birdcount(poly, builtup_raster, builtupraster_transform):
    outputs = []
    # Get observation records from GBIF
    
    observations = []
    
    if poly.type == 'MultiPolygon':
        poly = unary_union(poly)
    
    if str(poly) != 'GEOMETRYCOLLECTION EMPTY':
        box = boundingbox_wkt(poly)

        offset = -LIMIT
        while offset == -LIMIT or not results['endOfRecords']:
            offset += LIMIT
            url = '{0}?dataset_key={1}&taxon_key={2}&year={3},{4}&geometry={5}&limit={6}&offset={7}&hasCoordinate=true'.format(API_URL, DATASETKEY, TAXON_KEY, STARTYEAR, ENDYEAR, box, LIMIT, offset)
            resp = requests.get(url)
            results = resp.json()
            print('  {0}: {1}/{2}'.format(TAXON, results['offset'], results['count']))
            # Note spatial subsetting of points happens below (twice) as part of the conditions in the list comprehensions
            observations += [{
                'species': i['species'],
                'lat': i['decimalLatitude'],  # We don't really need to save lat/lon for this
                'lon': i['decimalLongitude'],
            } for i in results['results'] if 'species' in i.keys() and Point(float(i['decimalLongitude']), float(i['decimalLatitude'])).within(poly)]
        observations = [j for j in observations if point_query(Point((j['lon'], j['lat'])), builtup_raster, affine=builtupraster_transform)[0] != 0]
        # Estimate species counts by estimating asymptote of species-accumulation curve created when observation order is randomized
        # Final estimate is average over NUM_CURVEFITS estimates

        #count_estimate = None
        if len(observations) > 1:
            taxon_observations = [i['species'] for i in observations]
            asymptotes = []
            tries = 0
            while len(asymptotes) < NUM_CURVEFITS:   # Different observation-orders give different results, so average over many
                tries += 1
                taxon_observations.sort(key=lambda x: random.random())                    # Randomize order of observations
                sac = []                                                            # Initialize species accumulation curve data
                for obs_count in range(1, len(taxon_observations)):                       # Go through observation list from beginning
                    sac.append(len(set(taxon_observations[:obs_count])))                  # and count unique species from start to index
                if len(sac) > 5 and tries <= 1000:          # Avoid letting infinite-species errors stop the process
                    try:
                        asymptotes.append(scipy.optimize.curve_fit(lambda x,a,b,c: -((a*np.exp(-b*x))+c), list(range(1, len(sac)+1)), sac)[0][2])
                    except:
                        pass
                else:
                    asymptotes.append(-1)
            if -1 in asymptotes:
                count_estimate = -9999
            else:
                count_estimate = -np.mean(asymptotes)
            return count_estimate
    return -9999

# %%
def do_one_geom(row):
    poly = row[0]
    if poly.type == 'Polygon':
        poly = MultiPolygon([poly])
    
    box = boundingbox_wkt(poly)
    products = terracat.get_products('urn:eop:VITO:ESA_WorldCover_10m_2020_V1', geometry=box)
    
    # Create mosaic raster of Worldcover rasters downloaded from ESA
    rasters_to_mosaic = []
    for product in products:
        if not '{0}dir'.format(product.title) in os.listdir('.'):
            terracat.download_file(product.data[0], '{0}dir'.format(product.title))
        raster = rasterio.open('{0}dir/{0}_Map.tif'.format(product.title))
        rasters_to_mosaic.append(raster)

    mosaic, mosaic_transform = rmerge(rasters_to_mosaic)
    
    # Clip raster to district boundary
    clipped_raster, clip_transform = mask_raster_with_geometry(mosaic[0], mosaic_transform, poly, crop=True)
    # Classify clipped raster as habitat/nonhabitat
    builtup_raster = classify_builtup(clipped_raster)
    
    birdcount = get_birdcount(poly, builtup_raster, clip_transform)
    return birdcount

# %%
for i in range(len(boundary_georef)):
    if not OUTPUT_FILENAME in os.listdir('.'):
        so_far_df = pd.DataFrame()
        so_far_df.to_csv(OUTPUT_FILENAME)
        so_far = []
    else:
        so_far_df = pd.read_csv(OUTPUT_FILENAME)
        so_far = [so_far_df.iloc[j]['geo_id'] for j in range(len(so_far_df))]
    
    most_recent = []
    for boundary_name in ['aoi_boundary_name', 'units_boundary_name']:
        if type(boundary_georef.loc[i, boundary_name]) != float: # sometimes boundary_id is nan
            boundary_id = boundary_georef.loc[i, 'geo_name']+'-' + boundary_georef.loc[i, boundary_name]
            if not boundary_id in so_far:
                print(boundary_id)
                boundary_path = aws_s3_dir +'/boundaries/v_0/boundary-' + boundary_id + '.geojson'
                boundary_geo = requests.get(boundary_path).json()
                temp_gdf = gpd.GeoDataFrame.from_features(boundary_geo)
                temp_gdf['SICB-3'] = temp_gdf.apply(do_one_geom, axis=1)
                most_recent.append(temp_gdf.copy())
    # Delete WorldCover rasters to prevent filling up disk
    for directoryname in os.listdir('.'):
        if directoryname[:15] == 'ESA_WorldCover_':
            for filename in os.listdir(directoryname):
                os.remove('{0}/{1}'.format(directoryname, filename))
            os.rmdir(directoryname)
    result = pd.concat([so_far_df] + most_recent, axis=0)
    result[['geometry', 'geo_id', 'geo_level', 'geo_name', 'geo_parent_name', 'creation_date', 'SICB-3']].to_csv(OUTPUT_FILENAME)
# Out:
# ARG-Mendoza-ADM3union
#   Aves: 0/863
#   Aves: 300/863
#   Aves: 600/863
# ARG-Mendoza-ADM3
#   Aves: 0/41
#   Aves: 0/1
#   Aves: 0/9
#   Aves: 0/12
#   Aves: 0/4
#   Aves: 0/7
#   Aves: 0/9
#   Aves: 0/55
#   Aves: 0/140
#   Aves: 0/1
#   Aves: 0/1
#   Aves: 0/0
#   Aves: 0/1
#   Aves: 0/3
#   Aves: 0/19
#   Aves: 0/9
#   Aves: 0/4
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/1
#   Aves: 0/2
#   Aves: 0/0
#   Aves: 0/1
#   Aves: 0/0
#   Aves: 0/4
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/5
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/1
#   Aves: 0/0
#   Aves: 0/2
#   Aves: 0/7
#   Aves: 0/5
#   Aves: 0/1
#   Aves: 0/5
#   Aves: 0/1
#   Aves: 0/2
#   Aves: 0/0
#   Aves: 0/1
#   Aves: 0/87
#   Aves: 0/26
#   Aves: 0/1
#   Aves: 0/0
#   Aves: 0/8
#   Aves: 0/1
#   Aves: 0/38
#   Aves: 0/10
#   Aves: 0/2
#   Aves: 0/1
#   Aves: 0/36
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/2
#   Aves: 0/0
#   Aves: 0/310
#   Aves: 300/310
#   Aves: 0/1
#   Aves: 0/136
#   Aves: 0/2
#   Aves: 0/0
#   Aves: 0/8
#   Aves: 0/8
#   Aves: 0/16
#   Aves: 0/0
#   Aves: 0/6
#   Aves: 0/13
#   Aves: 0/2
#   Aves: 0/156
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/91
#   Aves: 0/130
# ARG-Mar_del_Plata-ADM3
#   Aves: 0/59
# ARG-Mar_del_Plata-ADM4
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/4
#   Aves: 0/0
#   Aves: 0/1
#   Aves: 0/1
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/1
#   Aves: 0/1
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/2
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/49
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/8
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/2
#   Aves: 0/14
#   Aves: 0/0
#   Aves: 0/2
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/3
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/7
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/1
#   Aves: 0/1
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/28
#   Aves: 0/1
#   Aves: 0/0
#   Aves: 0/29
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/1
#   Aves: 0/0
#   Aves: 0/1
#   Aves: 0/1
#   Aves: 0/0
#   Aves: 0/2
# ARG-Mar_del_Plata-ADM2
#   Aves: 0/60
# ARG-Ushuaia-ADM4
#   Aves: 0/1008
#   Aves: 300/1008
#   Aves: 600/1008
#   Aves: 900/1008
# ARG-Ushuaia-ADM5
#   Aves: 0/3
#   Aves: 0/0
#   Aves: 0/87
#   Aves: 0/16
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/11
#   Aves: 0/0
#   Aves: 0/3
#   Aves: 0/0
#   Aves: 0/8
#   Aves: 0/0
#   Aves: 0/5
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/1
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/1
#   Aves: 0/1
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/2
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/4
#   Aves: 0/1
#   Aves: 0/1
#   Aves: 0/1
#   Aves: 0/1
#   Aves: 0/2
#   Aves: 0/7
#   Aves: 0/0
#   Aves: 0/2
#   Aves: 0/19
#   Aves: 0/0
#   Aves: 0/8
#   Aves: 0/3
#   Aves: 0/6
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/1
#   Aves: 0/0
#   Aves: 0/3
#   Aves: 0/2
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/1
#   Aves: 0/0
#   Aves: 0/37
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/1
#   Aves: 0/2
#   Aves: 0/2
#   Aves: 0/1
#   Aves: 0/0
#   Aves: 0/1
#   Aves: 0/20
#   Aves: 0/84
#   Aves: 0/1
#   Aves: 0/9
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/3
#   Aves: 0/2
#   Aves: 0/1
#   Aves: 0/2
#   Aves: 0/0
#   Aves: 0/69
#   Aves: 0/96
#   Aves: 0/0
#   Aves: 0/1
#   Aves: 0/4
#   Aves: 0/3
#   Aves: 0/0
# ARG-Ushuaia-ADM3
#   Aves: 0/1008
#   Aves: 300/1008
#   Aves: 600/1008
#   Aves: 900/1008
# ARG-Salta-ADM2union
#   Aves: 0/241
# ARG-Salta-ADM3
#   Aves: 0/102
#   Aves: 0/24
#   Aves: 0/6
#   Aves: 0/2
#   Aves: 0/3
#   Aves: 0/28
#   Aves: 0/10
#   Aves: 0/54
# ARG-Buenos_Aires-ADM2union
#   Aves: 0/21838
#   Aves: 300/21838
#   Aves: 600/21838
#   Aves: 900/21838
#   Aves: 1200/21838
#   Aves: 1500/21838
#   Aves: 1800/21838
#   Aves: 2100/21838
#   Aves: 2400/21838
#   Aves: 2700/21838
#   Aves: 3000/21838
#   Aves: 3300/21838
#   Aves: 3600/21838
#   Aves: 3900/21838
#   Aves: 4200/21838
#   Aves: 4500/21838
#   Aves: 4800/21838
#   Aves: 5100/21838
#   Aves: 5400/21838
#   Aves: 5700/21838
#   Aves: 6000/21838
#   Aves: 6300/21838
#   Aves: 6600/21838
#   Aves: 6900/21838
#   Aves: 7200/21838
#   Aves: 7500/21838
#   Aves: 7800/21838
#   Aves: 8100/21838
#   Aves: 8400/21838
#   Aves: 8700/21838
#   Aves: 9000/21838
#   Aves: 9300/21838
#   Aves: 9600/21838
#   Aves: 9900/21838
#   Aves: 10200/21838
#   Aves: 10500/21838
#   Aves: 10800/21838
#   Aves: 11100/21838
#   Aves: 11400/21838
#   Aves: 11700/21838
#   Aves: 12000/21838
#   Aves: 12300/21838
#   Aves: 12600/21838
#   Aves: 12900/21838
#   Aves: 13200/21838
#   Aves: 13500/21838
#   Aves: 13800/21838
#   Aves: 14100/21838
#   Aves: 14400/21838
#   Aves: 14700/21838
#   Aves: 15000/21838
#   Aves: 15300/21838
#   Aves: 15600/21838
#   Aves: 15900/21838
#   Aves: 16200/21838
#   Aves: 16500/21838
#   Aves: 16800/21838
#   Aves: 17100/21838
#   Aves: 17400/21838
#   Aves: 17700/21838
#   Aves: 18000/21838
#   Aves: 18300/21838
#   Aves: 18600/21838
#   Aves: 18900/21838
#   Aves: 19200/21838
#   Aves: 19500/21838
#   Aves: 19800/21838
#   Aves: 20100/21838
#   Aves: 20400/21838
#   Aves: 20700/21838
#   Aves: 21000/21838
#   Aves: 21300/21838
#   Aves: 21600/21838
# ARG-Buenos_Aires-ADM2
#   Aves: 0/1
#   Aves: 0/54
#   Aves: 0/70
#   Aves: 0/690
#   Aves: 300/690
#   Aves: 600/690
#   Aves: 0/187
#   Aves: 0/1562
#   Aves: 300/1562
#   Aves: 600/1562
#   Aves: 900/1562
#   Aves: 1200/1562
#   Aves: 1500/1562
#   Aves: 0/37
#   Aves: 0/229
#   Aves: 0/67
#   Aves: 0/23
#   Aves: 0/46
#   Aves: 0/158
#   Aves: 0/53
#   Aves: 0/505
#   Aves: 300/505
#   Aves: 0/2184
#   Aves: 300/2184
#   Aves: 600/2184
#   Aves: 900/2184
#   Aves: 1200/2184
#   Aves: 1500/2184
#   Aves: 1800/2184
#   Aves: 2100/2184
#   Aves: 0/304
#   Aves: 300/304
#   Aves: 0/70
#   Aves: 0/1885
#   Aves: 300/1885
#   Aves: 600/1885
#   Aves: 900/1885
#   Aves: 1200/1885
#   Aves: 1500/1885
#   Aves: 1800/1885
#   Aves: 0/2040
#   Aves: 300/2040
#   Aves: 600/2040
#   Aves: 900/2040
#   Aves: 1200/2040
#   Aves: 1500/2040
#   Aves: 1800/2040
#   Aves: 0/181
#   Aves: 0/94
#   Aves: 0/149
#   Aves: 0/102
#   Aves: 0/16
#   Aves: 0/192
#   Aves: 0/438
#   Aves: 300/438
#   Aves: 0/789
#   Aves: 300/789
#   Aves: 600/789
#   Aves: 0/28
#   Aves: 0/375
#   Aves: 300/375
#   Aves: 0/47
#   Aves: 0/66
#   Aves: 0/56
#   Aves: 0/129
#   Aves: 0/228
#   Aves: 0/678
#   Aves: 300/678
#   Aves: 600/678
#   Aves: 0/169
#   Aves: 0/108
#   Aves: 0/563
#   Aves: 300/563
# BRA-Teresina-ADM4union
#   Aves: 0/14
# BRA-Teresina-ADM4
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/1
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/1
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/2
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/1
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/1
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
# BRA-Teresina-ADM2union
#   Aves: 0/34
# BRA-Teresina-ADM2
#   Aves: 0/13
#   Aves: 0/0
#   Aves: 0/9
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/2
#   Aves: 0/0
#   Aves: 0/0
# BRA-Florianopolis-ADM4union
#   Aves: 0/132
# BRA-Florianopolis-ADM4
#   Aves: 0/4
#   Aves: 0/7
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/1
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/1
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/16
#   Aves: 0/5
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/16
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/23
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/1
#   Aves: 0/2
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/14
#   Aves: 0/0
#   Aves: 0/2
#   Aves: 0/3
#   Aves: 0/115
#   Aves: 0/4
#   Aves: 0/0
#   Aves: 0/4
#   Aves: 0/13
#   Aves: 0/1
#   Aves: 0/23
#   Aves: 0/5
#   Aves: 0/1
#   Aves: 0/2
#   Aves: 0/20
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
#   Aves: 0/0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [16], line 19
#      17             boundary_geo = requests.get(boundary_path).json()
#      18             temp_gdf = gpd.GeoDataFrame.from_features(boundary_geo)
# ---> 19             temp_gdf['SICB-3'] = temp_gdf.apply(do_one_geom, axis=1)
#      20             most_recent.append(temp_gdf.copy())
#      21 # Delete WorldCover rasters to prevent filling up disk
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/geopandas/geodataframe.py:1511, in GeoDataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    1509 @doc(pd.DataFrame)
#    1510 def apply(self, func, axis=0, raw=False, result_type=None, args=(), **kwargs):
# -> 1511     result = super().apply(
#    1512         func, axis=axis, raw=raw, result_type=result_type, args=args, **kwargs
#    1513     )
#    1514     # Reconstruct gdf if it was lost by apply
#    1515     if (
#    1516         isinstance(result, DataFrame)
#    1517         and self._geometry_column_name in result.columns
#    1518     ):
#    1519         # axis=1 apply will split GeometryDType to object, try and cast back
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pandas/core/frame.py:8848, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8837 from pandas.core.apply import frame_apply
#    8839 op = frame_apply(
#    8840     self,
#    8841     func=func,
#    (...)
#    8846     kwargs=kwargs,
#    8847 )
# -> 8848 return op.apply().__finalize__(self, method="apply")
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pandas/core/apply.py:733, in FrameApply.apply(self)
#     730 elif self.raw:
#     731     return self.apply_raw()
# --> 733 return self.apply_standard()
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pandas/core/apply.py:857, in FrameApply.apply_standard(self)
#     856 def apply_standard(self):
# --> 857     results, res_index = self.apply_series_generator()
#     859     # wrap results
#     860     return self.wrap_results(results, res_index)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pandas/core/apply.py:873, in FrameApply.apply_series_generator(self)
#     870 with option_context("mode.chained_assignment", None):
#     871     for i, v in enumerate(series_gen):
#     872         # ignore SettingWithCopy here in case the user mutates
# --> 873         results[i] = self.f(v)
#     874         if isinstance(results[i], ABCSeries):
#     875             # If we have a view on v, we need to make a copy because
#     876             #  series_generator will swap out the underlying data
#     877             results[i] = results[i].copy(deep=False)
#
# Cell In [15], line 17, in do_one_geom(row)
#      14     raster = rasterio.open('{0}dir/{0}_Map.tif'.format(product.title))
#      15     rasters_to_mosaic.append(raster)
# ---> 17 mosaic, mosaic_transform = rmerge(rasters_to_mosaic)
#      19 # Clip raster to district boundary
#      20 clipped_raster, clip_transform = mask_raster_with_geometry(mosaic[0], mosaic_transform, poly, crop=True)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/rasterio/merge.py:386, in merge(datasets, bounds, res, nodata, dtype, precision, indexes, output_count, resampling, method, target_aligned_pixels, dst_path, dst_kwds)
#     383     region_mask = region == nodataval
#     385 # Ensure common shape, resolving issue #2202.
# --> 386 temp = temp_src[:, : region.shape[1], : region.shape[2]]
#     387 temp_mask = np.ma.getmask(temp)
#     388 copyto(region, temp, region_mask, temp_mask, index=idx, roff=roff, coff=coff)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/numpy/ma/core.py:3211, in MaskedArray.__getitem__(self, indx)
#    3208             output.fill_value = fill_value
#    3209     return output
# -> 3211 def __getitem__(self, indx):
#    3212     """
#    3213     x.__getitem__(y) <==> x[y]
#    3214
#    3215     Return the item described by i, as a masked array.
#    3216
#    3217     """
#    3218     # We could directly use ndarray.__getitem__ on self.
#    3219     # But then we would have to modify __array_finalize__ to prevent the
#    3220     # mask of being reshaped if it hasn't been set up properly yet
#    3221     # So it's easier to stick to the current version
#
# KeyboardInterrupt:

# %%
outdf = result[['geometry', 'geo_id', 'geo_level', 'geo_name', 'geo_parent_name', 'creation_date', 'SICB-3']]

# %%
# connect to s3

import boto3

aws_key = "AKIA4GK7IHHC5RCMFKEG"
aws_secret = "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"

s3 = boto3.resource(
    service_name='s3',
    aws_access_key_id=aws_key,
    aws_secret_access_key=aws_secret
)

# upload to aws
key_data = 'indicators/biodiversity/BIO-3.csv'
bucket_name = 'cities-urbanshift' 
outdf.to_csv(
    f"s3://{bucket_name}/{key_data}",
    index=False,
    storage_options={
        "key": aws_key,
        "secret": aws_secret
    },
)

# make it public
object_acl = s3.ObjectAcl(bucket_name,key_data)
response = object_acl.put(ACL='public-read')

# %%
import boto3

aws_key = "AKIA4GK7IHHC5RCMFKEG"
aws_secret = "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"

# %%
ofile = open('test.csv', 'w')
ofile.write('test,test,test\n')
ofile.close()

# %%
import pandas as pd

# %%
outdf = pd.read_csv('test.csv')

# %%
outdf.to_csv(
    f"s3://{bucket_name}/{key_data}",
    index=False,
    storage_options={
        "key": aws_key,
        "secret": aws_secret
    },
)

# %%
s3 = boto3.resource(
    service_name='s3',
    aws_access_key_id=aws_key,
    aws_secret_access_key=aws_secret
)
key_data = 'indicators/biodiversity/test.csv'
bucket_name = 'cities-urbanshift' 
object_acl = s3.ObjectAcl(bucket_name,key_data)

# %%
my_bucket = s3.Bucket(bucket_name)

# %%
for my_bucket_object in my_bucket.objects.all():
    print(my_bucket_object.key)
# Out:
# baseline-indicators/
# baseline-indicators/biodiversity/
# baseline-indicators/biodiversity/data/
# baseline-indicators/biodiversity/data/CRI-San_Jose/
# baseline-indicators/biodiversity/data/CRI-San_Jose/CRI-San_Jose-ESA-landcover-2020.tif
# baseline-indicators/biodiversity/data/CRI-San_Jose/CRI-San_Jose-GAIA_impervious_surfaces-2018.tif
# baseline-indicators/biodiversity/data/CRI-San_Jose/CRI-San_Jose-GBIF-species_observation-2020.geojson
# baseline-indicators/biodiversity/data/CRI-San_Jose/CRI-San_Jose-GLAD-landclasses-2000.tif
# baseline-indicators/biodiversity/data/CRI-San_Jose/CRI-San_Jose-GLAD-landclasses-2020.tif
# baseline-indicators/biodiversity/data/CRI-San_Jose/CRI-San_Jose-GLAD_habitat_changes-2000_2020.tif
# baseline-indicators/biodiversity/data/CRI-San_Jose/CRI-San_Jose-IUCN-RedList_counts.xlsx
# baseline-indicators/biodiversity/data/CRI-San_Jose/CRI-San_Jose-KBA-2022.geojson
# baseline-indicators/biodiversity/data/CRI-San_Jose/CRI-San_Jose-LSTmean-20210305.tif
# baseline-indicators/biodiversity/data/CRI-San_Jose/CRI-San_Jose-OSM-recreational_services-2022.geojson
# baseline-indicators/biodiversity/data/CRI-San_Jose/CRI-San_Jose-TML-trees-2020-out.tif
# baseline-indicators/biodiversity/data/CRI-San_Jose/CRI-San_Jose-TML-trees-2020.tif
# baseline-indicators/biodiversity/data/CRI-San_Jose/CRI-San_Jose-WDPA-protected_areas_2022.geojson
# baseline-indicators/biodiversity/data/CRI-San_Jose/CRI-San_Jose-WorldPop-population-2020.tif
# baseline-indicators/biodiversity/data/biodiversity_map_layers_protected_areas_costarica.geojson
# baseline-indicators/biodiversity/data/biodiversity_map_layers_protected_areas_sanjose.geojson
# baseline-indicators/biodiversity/data/boundaries-CRI-San_Jose-ADM2.geojson
# baseline-indicators/biodiversity/data/boundaries-CRI-San_Jose-municipality.geojson
# baseline-indicators/biodiversity/data/indicators_biodiversity_CRI-San_Jose-esa-worldcover-2020.tif
# baseline-indicators/biodiversity/data/protectedarea_percent_by_municipality.csv
# baseline-indicators/biodiversity/maps/
# baseline-indicators/biodiversity/maps/CRI-San_Jose_SCIB-1.png
# baseline-indicators/biodiversity/maps/CRI-San_Jose_SCIB-1_webmap.html
# baseline-indicators/biodiversity/reports/
# baseline-indicators/biodiversity/reports/UrbanShift-Biodiversity-ARG-Buenos_Aires.html
# baseline-indicators/biodiversity/reports/UrbanShift-Biodiversity-ARG-Mendoza.html
# baseline-indicators/biodiversity/reports/UrbanShift-Biodiversity-ARG-Salta.html
# baseline-indicators/biodiversity/reports/UrbanShift-Biodiversity-ARG-Ushaia.html
# baseline-indicators/biodiversity/reports/UrbanShift-Biodiversity-ARG-Ushuaia.html
# baseline-indicators/biodiversity/reports/UrbanShift-Biodiversity-BRA-Belem.html
# baseline-indicators/biodiversity/reports/UrbanShift-Biodiversity-BRA-Florianopolis.html
# baseline-indicators/biodiversity/reports/UrbanShift-Biodiversity-BRA-Florianopolois.html
# baseline-indicators/biodiversity/reports/UrbanShift-Biodiversity-BRA-Teresina.html
# baseline-indicators/biodiversity/reports/UrbanShift-Biodiversity-CHN-Chengdu.html
# baseline-indicators/biodiversity/reports/UrbanShift-Biodiversity-CHN-Chongqing.html
# baseline-indicators/biodiversity/reports/UrbanShift-Biodiversity-CHN-Ningbo.html
# baseline-indicators/biodiversity/reports/UrbanShift-Biodiversity-CRI-San_Jose-opt.html
# baseline-indicators/biodiversity/reports/UrbanShift-Biodiversity-CRI-San_Jose.html
# baseline-indicators/biodiversity/reports/UrbanShift-Biodiversity-IDN-Balikpapan.html
# baseline-indicators/biodiversity/reports/UrbanShift-Biodiversity-IDN-Bitung.html
# baseline-indicators/biodiversity/reports/UrbanShift-Biodiversity-IDN-Jakarta.html
# baseline-indicators/biodiversity/reports/UrbanShift-Biodiversity-IDN-Palembang.html
# baseline-indicators/biodiversity/reports/UrbanShift-Biodiversity-IDN-Semarang.html
# baseline-indicators/biodiversity/reports/UrbanShift-Biodiversity-IND-Chennai.html
# baseline-indicators/biodiversity/reports/UrbanShift-Biodiversity-IND-Pune.html
# baseline-indicators/biodiversity/reports/UrbanShift-Biodiversity-IND-Surat.html
# baseline-indicators/biodiversity/reports/UrbanShift-Biodiversity-Indicators-Pipeline.html
# baseline-indicators/biodiversity/reports/UrbanShift-Biodiversity-MAR-Marrakech.html
# baseline-indicators/biodiversity/reports/UrbanShift-Biodiversity-RWA-Kigali.html
# baseline-indicators/biodiversity/reports/UrbanShift-Biodiversity-SLE-Freetown.html
# baseline-indicators/biodiversity/reports/UrbanShift-Biodiversity-SLE-Freetown_region.html
# baseline-indicators/biodiversity/reports/UrbanShift-Biodiversity-SanJose-complete.html
# baseline-indicators/biodiversity/reports/UrbanShift-Biodiversity-SanJose-dev.html
# baseline-indicators/biodiversity/reports/UrbanShift-Biodiversity-SanJose.html
# baseline-indicators/biodiversity/tables/
# baseline-indicators/biodiversity/tables/CRI-San_Jose_indicator_SCIB_1.csv
# baseline-indicators/biodiversity/tables/IUCN RedList counts Arthropoda.csv
# baseline-indicators/biodiversity/tables/IUCN RedList counts Aves.csv
# baseline-indicators/biodiversity/tables/IUCN RedList counts Tracheophyta.csv
# baseline-indicators/biodiversity/tables/SICB_4_table.csv
# baseline-indicators/biodiversity/tables/biodiversity_baseline_newmunis.xlsx
# baseline-indicators/biodiversity/tables/biodiversity_baseline_newmunis_main.csv
# baseline-indicators/greenspace/
# baseline-indicators/greenspace/city_landcover_dw_stat.csv
# baseline-indicators/greenspace/maps/
# baseline-indicators/greenspace/maps/Kigali-percent-vegetation-land-DW-2020.html
# data/
# data/Land-surface-temperature/
# data/Land-surface-temperature/CRI-San_Jose_LSTmean_2021.tif
# data/amenity/
# data/amenity/amenity_ARG-Buenos_Aires.geojson
# data/amenity/amenity_ARG-Mar_del_Plata.geojson
# data/amenity/amenity_ARG-Mendoza.geojson
# data/amenity/amenity_ARG-Salta.geojson.geojson
# data/amenity/amenity_ARG-Ushuaia.geojson
# data/amenity/amenity_BRA-Belem.geojson
# data/amenity/amenity_BRA-Florianopolois.geojson
# data/amenity/amenity_BRA-Teresina.geojson
# data/amenity/amenity_CHN-Chengdu.geojson
# data/amenity/amenity_CHN-Chongqing.geojson
# data/amenity/amenity_CHN-Ningbo.geojson
# data/amenity/amenity_CRI-San_Jose.geojson
# data/amenity/amenity_IDN-Balikpapan.geojson
# data/amenity/amenity_IDN-Bitung.geojson
# data/amenity/amenity_IDN-Jakarta.geojson
# data/amenity/amenity_IDN-Palembang.geojson
# data/amenity/amenity_IDN-Semarang.geojson
# data/amenity/amenity_IND-Chennai.geojson
# data/amenity/amenity_IND-Pune.geojson
# data/amenity/amenity_IND-Surat.geojson
# data/amenity/amenity_MAR-Marrakech.geojson
# data/amenity/amenity_RWA-Kigali.geojson
# data/amenity/amenity_SLE-Freetown_region.geojson
# data/amenity/recreational_servcies/
# data/amenity/recreational_servcies/CRI-San_Jose_parks_points.geojson
# data/amenity/recreational_servcies/CRI-San_Jose_parks_polygons.geojson
# data/biodiversity/
# data/biodiversity/CRI-San_Jose-GLAD_habitat_changes_2000_2020.tif
# data/biodiversity/GBIF-ARG-Buenos_Aires.geojson
# data/biodiversity/GBIF-ARG-Mar_del_Plata.geojson
# data/biodiversity/GBIF-ARG-Mendoza.geojson
# data/biodiversity/GBIF-ARG-Salta.geojson
# data/biodiversity/GBIF-ARG-Ushuaia.geojson
# data/biodiversity/GBIF-BRA-Belem.geojson
# data/biodiversity/GBIF-BRA-Florianopolois.geojson
# data/biodiversity/GBIF-BRA-Teresina.geojson
# data/biodiversity/GBIF-CHN-Chengdu.geojson
# data/biodiversity/GBIF-CHN-Chongqing.geojson
# data/biodiversity/GBIF-CHN-Ningbo.geojson
# data/biodiversity/GBIF-CRI-San_Jose.geojson
# data/biodiversity/GBIF-IDN-Balikpapan.geojson
# data/biodiversity/GBIF-IDN-Bitung.geojson
# data/biodiversity/GBIF-IDN-Jakarta.geojson
# data/biodiversity/GBIF-IDN-Palembang.geojson
# data/biodiversity/GBIF-IDN-Semarang.geojson
# data/biodiversity/GBIF-IND-Chennai.geojson
# data/biodiversity/GBIF-IND-Pune.geojson
# data/biodiversity/GBIF-IND-Surat.geojson
# data/biodiversity/GBIF-MAR-Marrakech.geojson
# data/biodiversity/GBIF-RWA-Kigali.geojson
# data/biodiversity/GBIF-SLE-Freetown_region.geojson
# data/biodiversity/KBA/
# data/biodiversity/KBA/CRI-San_Jose_kba.geojson
# data/biodiversity/WDPA/
# data/biodiversity/WDPA/WDPA_CRI-San_Jose.geojson
# data/biodiversity/biodiversity_map_layers_birds2020_sanjose.geojson
# data/boundaries/
# data/boundaries/ADM1/
# data/boundaries/ADM1/boundary-ARG-Buenos_Aires-ADM1.geojson
# data/boundaries/ADM1/boundary-ARG-Mar_del_Plata-ADM1.geojson
# data/boundaries/ADM1/boundary-ARG-Mendoza-ADM1.geojson
# data/boundaries/ADM1/boundary-ARG-Salta-ADM1.geojson
# data/boundaries/ADM1/boundary-ARG-Ushuaia-ADM1.geojson
# data/boundaries/ADM1/boundary-BRA-Belem-ADM1.geojson
# data/boundaries/ADM1/boundary-BRA-Florianopolois-ADM1.geojson
# data/boundaries/ADM1/boundary-BRA-Teresina-ADM1.geojson
# data/boundaries/ADM1/boundary-CHN-Chengdu-ADM1.geojson
# data/boundaries/ADM1/boundary-CHN-Chongqing-ADM1.geojson
# data/boundaries/ADM1/boundary-CHN-Ningbo-ADM1.geojson
# data/boundaries/ADM1/boundary-CRI-San_Jose-ADM1.geojson
# data/boundaries/ADM1/boundary-IDN-Balikpapan-ADM1.geojson
# data/boundaries/ADM1/boundary-IDN-Bitung-ADM1.geojson
# data/boundaries/ADM1/boundary-IDN-Jakarta-ADM1.geojson
# data/boundaries/ADM1/boundary-IDN-Palembang-ADM1.geojson
# data/boundaries/ADM1/boundary-IDN-Semarang-ADM1.geojson
# data/boundaries/ADM1/boundary-IND-Chennai-ADM1.geojson
# data/boundaries/ADM1/boundary-IND-Pune-ADM1.geojson
# data/boundaries/ADM1/boundary-IND-Surat-ADM1.geojson
# data/boundaries/ADM1/boundary-MAR-Marrakech-ADM1.geojson
# data/boundaries/ADM1/boundary-RWA-Kigali-ADM1.geojson
# data/boundaries/ADM1/boundary-SLE-Freetown_region-ADM1.geojson
# data/boundaries/ADM1/boundary_cities_ADM1.geojson
# data/boundaries/ADM1/old/
# data/boundaries/ADM1/old/admin_boundaries_CRI-San_Jose-ADM1.geojson
# data/boundaries/ADM2/
# data/boundaries/ADM2/boundary-ARG-Mar_del_Plata-ADM2.geojson
# data/boundaries/ADM2/boundary-CRI-San_Jose-ADM2.geojson
# data/boundaries/ADM3/
# data/boundaries/ADM3/boundary-CHN-Ningbo-ADM3.geojson
# data/boundaries/ADM3/boundary-CHN-Ningbo-ADM3union.geojson
# data/boundaries/ADM3/boundary-IDN-Balikpapan-ADM3.geojson
# data/boundaries/ADM3/boundary-IDN-Semarang-ADM3.geojson
# data/boundaries/CRI-San_Jose-boundary-ADM2.geojson
# data/boundaries/CRI-San_Jose-boundary.geojson
# data/boundaries/LimiteCantonal_GAM.geojson
# data/boundaries/RWA-Kigali-boundary.geojson
# data/boundaries/SLE-Freetown_core-boundary.geojson
# data/boundaries/administrative_boundaries.geojson
# data/boundaries/city_georef.csv
# data/boundaries/city_georef_adm2.csv
# data/boundaries/urban_edge_t3.geojson
# data/boundaries/v_0/
# data/boundaries/v_0/boundary-ARG-Buenos_Aires-ADM1.geojson
# data/boundaries/v_0/boundary-ARG-Buenos_Aires-ADM2.geojson
# data/boundaries/v_0/boundary-ARG-Buenos_Aires-ADM2union.geojson
# data/boundaries/v_0/boundary-ARG-Mar_del_Plata-ADM2.geojson
# data/boundaries/v_0/boundary-ARG-Mar_del_Plata-ADM3.geojson
# data/boundaries/v_0/boundary-ARG-Mar_del_Plata-ADM4.geojson
# data/boundaries/v_0/boundary-ARG-Mendoza-ADM2.geojson
# data/boundaries/v_0/boundary-ARG-Mendoza-ADM3.geojson
# data/boundaries/v_0/boundary-ARG-Mendoza-ADM3union.geojson
# data/boundaries/v_0/boundary-ARG-Salta-ADM2.geojson
# data/boundaries/v_0/boundary-ARG-Salta-ADM2union.geojson
# data/boundaries/v_0/boundary-ARG-Salta-ADM3.geojson
# data/boundaries/v_0/boundary-ARG-Ushuaia-ADM3.geojson
# data/boundaries/v_0/boundary-ARG-Ushuaia-ADM4.geojson
# data/boundaries/v_0/boundary-ARG-Ushuaia-ADM5.geojson
# data/boundaries/v_0/boundary-BRA-Belem-ADM2.geojson
# data/boundaries/v_0/boundary-BRA-Belem-ADM2union.geojson
# data/boundaries/v_0/boundary-BRA-Belem-ADM3.geojson
# data/boundaries/v_0/boundary-BRA-Belem-ADM4.geojson
# data/boundaries/v_0/boundary-BRA-Belem-ADM4union.geojson
# data/boundaries/v_0/boundary-BRA-Florianopolis-ADM2.geojson
# data/boundaries/v_0/boundary-BRA-Florianopolis-ADM2union.geojson
# data/boundaries/v_0/boundary-BRA-Florianopolis-ADM4.geojson
# data/boundaries/v_0/boundary-BRA-Florianopolis-ADM4union.geojson
# data/boundaries/v_0/boundary-BRA-Teresina-ADM2.geojson
# data/boundaries/v_0/boundary-BRA-Teresina-ADM2union.geojson
# data/boundaries/v_0/boundary-BRA-Teresina-ADM4.geojson
# data/boundaries/v_0/boundary-BRA-Teresina-ADM4union.geojson
# data/boundaries/v_0/boundary-CHN-Chengdu-ADM3.geojson
# data/boundaries/v_0/boundary-CHN-Chengdu-ADM3union.geojson
# data/boundaries/v_0/boundary-CHN-Chongqing-ADM1.geojson
# data/boundaries/v_0/boundary-CHN-Chongqing-ADM3.geojson
# data/boundaries/v_0/boundary-CHN-Ningbo-ADM3.geojson
# data/boundaries/v_0/boundary-CHN-Ningbo-ADM3union.geojson
# data/boundaries/v_0/boundary-CHN-Ningbo-ADM4.geojson
# data/boundaries/v_0/boundary-CRI-San_Jose-ADM2.geojson
# data/boundaries/v_0/boundary-CRI-San_Jose-ADM2union.geojson
# data/boundaries/v_0/boundary-IDN-Balikpapan-ADM3.geojson
# data/boundaries/v_0/boundary-IDN-Balikpapan-ADM4.geojson
# data/boundaries/v_0/boundary-IDN-Balikpapan-ADM4union.geojson
# data/boundaries/v_0/boundary-IDN-Bitung-ADM2.geojson
# data/boundaries/v_0/boundary-IDN-Bitung-ADM3.geojson
# data/boundaries/v_0/boundary-IDN-Jakarta-ADM2.geojson
# data/boundaries/v_0/boundary-IDN-Jakarta-ADM4.geojson
# data/boundaries/v_0/boundary-IDN-Jakarta-ADM4union.geojson
# data/boundaries/v_0/boundary-IDN-Palembang-ADM2.geojson
# data/boundaries/v_0/boundary-IDN-Palembang-ADM3.geojson
# data/boundaries/v_0/boundary-IDN-Semarang-ADM1.geojson
# data/boundaries/v_0/boundary-IDN-Semarang-ADM3.geojson
# data/boundaries/v_0/boundary-IDN-Semarang-ADM4.geojson
# data/boundaries/v_0/boundary-IND-Chennai-ADM4.geojson
# data/boundaries/v_0/boundary-IND-Chennai-ADM4union.geojson
# data/boundaries/v_0/boundary-IND-Chennai-ADM6.geojson
# data/boundaries/v_0/boundary-IND-Chennai-ADM6union.geojson
# data/boundaries/v_0/boundary-IND-Pune-ADM4.geojson
# data/boundaries/v_0/boundary-IND-Pune-ADM4union.geojson
# data/boundaries/v_0/boundary-IND-Surat-ADM4.geojson
# data/boundaries/v_0/boundary-IND-Surat-ADM4union.geojson
# data/boundaries/v_0/boundary-MAR-Marrakech-ADM2.geojson
# data/boundaries/v_0/boundary-MAR-Marrakech-ADM5.geojson
# data/boundaries/v_0/boundary-RWA-Kigali-ADM4.geojson
# data/boundaries/v_0/boundary-RWA-Kigali-ADM4union.geojson
# data/boundaries/v_0/boundary-SLE-Freetown-ADM4city.geojson
# data/boundaries/v_0/boundary-SLE-Freetown-ADM4cityunion.geojson
# data/boundaries/v_0/boundary-SLE-Freetown-ADM4region.geojson
# data/boundaries/v_0/boundary-SLE-Freetown-ADM4regionunion.geojson
# data/boundaries/v_0/boundary-cities-urbanshift.geojson
# data/boundaries/v_0/boundary_georef.csv
# data/boundaries/v_0/raw/
# data/boundaries/v_0/raw/UrbanShift boundary file key.xlsx
# data/boundaries/v_0/raw/boundary-ARG-Buenos_Aires-ADM1.geojson
# data/boundaries/v_0/raw/boundary-ARG-Buenos_Aires-ADM2.geojson
# data/boundaries/v_0/raw/boundary-ARG-Buenos_Aires-ADM2union.geojson
# data/boundaries/v_0/raw/boundary-ARG-Mar_del_Plata-ADM2.geojson
# data/boundaries/v_0/raw/boundary-ARG-Mar_del_Plata-ADM3.geojson
# data/boundaries/v_0/raw/boundary-ARG-Mar_del_Plata-ADM4.geojson
# data/boundaries/v_0/raw/boundary-ARG-Mendoza-ADM2.geojson
# data/boundaries/v_0/raw/boundary-ARG-Mendoza-ADM3.geojson
# data/boundaries/v_0/raw/boundary-ARG-Mendoza-ADM3union.geojson
# data/boundaries/v_0/raw/boundary-ARG-Salta-ADM2.geojson
# data/boundaries/v_0/raw/boundary-ARG-Salta-ADM2union.geojson
# data/boundaries/v_0/raw/boundary-ARG-Salta-ADM3.geojson
# data/boundaries/v_0/raw/boundary-ARG-Ushuaia-ADM3.geojson
# data/boundaries/v_0/raw/boundary-ARG-Ushuaia-ADM4.geojson
# data/boundaries/v_0/raw/boundary-ARG-Ushuaia-ADM5.geojson
# data/boundaries/v_0/raw/boundary-BRA-Belem-ADM2.geojson
# data/boundaries/v_0/raw/boundary-BRA-Belem-ADM2union.geojson
# data/boundaries/v_0/raw/boundary-BRA-Belem-ADM3.geojson
# data/boundaries/v_0/raw/boundary-BRA-Belem-ADM4.geojson
# data/boundaries/v_0/raw/boundary-BRA-Belem-ADM4union.geojson
# data/boundaries/v_0/raw/boundary-BRA-Florianopolis-ADM2.geojson
# data/boundaries/v_0/raw/boundary-BRA-Florianopolis-ADM2union.geojson
# data/boundaries/v_0/raw/boundary-BRA-Florianopolis-ADM4.geojson
# data/boundaries/v_0/raw/boundary-BRA-Florianopolis-ADM4union.geojson
# data/boundaries/v_0/raw/boundary-BRA-Teresina-ADM2.geojson
# data/boundaries/v_0/raw/boundary-BRA-Teresina-ADM2union.geojson
# data/boundaries/v_0/raw/boundary-BRA-Teresina-ADM4.geojson
# data/boundaries/v_0/raw/boundary-BRA-Teresina-ADM4union.geojson
# data/boundaries/v_0/raw/boundary-CHN-Chengdu-ADM3.geojson
# data/boundaries/v_0/raw/boundary-CHN-Chengdu-ADM3union.geojson
# data/boundaries/v_0/raw/boundary-CHN-Chongqing-ADM1.geojson
# data/boundaries/v_0/raw/boundary-CHN-Chongqing-ADM3.geojson
# data/boundaries/v_0/raw/boundary-CHN-Ningbo-ADM3.geojson
# data/boundaries/v_0/raw/boundary-CHN-Ningbo-ADM3union.geojson
# data/boundaries/v_0/raw/boundary-CHN-Ningbo-ADM4.geojson
# data/boundaries/v_0/raw/boundary-CRI-San_Jose-ADM2.geojson
# data/boundaries/v_0/raw/boundary-CRI-San_Jose-ADM2union.geojson
# data/boundaries/v_0/raw/boundary-IDN-Balikpapan-ADM3.geojson
# data/boundaries/v_0/raw/boundary-IDN-Balikpapan-ADM4.geojson
# data/boundaries/v_0/raw/boundary-IDN-Balikpapan-ADM4union.geojson
# data/boundaries/v_0/raw/boundary-IDN-Bitung-ADM2.geojson
# data/boundaries/v_0/raw/boundary-IDN-Bitung-ADM3.geojson
# data/boundaries/v_0/raw/boundary-IDN-Jakarta-ADM2.geojson
# data/boundaries/v_0/raw/boundary-IDN-Jakarta-ADM4.geojson
# data/boundaries/v_0/raw/boundary-IDN-Jakarta-ADM4union.geojson
# data/boundaries/v_0/raw/boundary-IDN-Palembang-ADM2.geojson
# data/boundaries/v_0/raw/boundary-IDN-Palembang-ADM3.geojson
# data/boundaries/v_0/raw/boundary-IDN-Semarang-ADM1.geojson
# data/boundaries/v_0/raw/boundary-IDN-Semarang-ADM3.geojson
# data/boundaries/v_0/raw/boundary-IDN-Semarang-ADM4.geojson
# data/boundaries/v_0/raw/boundary-IND-Chennai-ADM4.geojson
# data/boundaries/v_0/raw/boundary-IND-Chennai-ADM4union.geojson
# data/boundaries/v_0/raw/boundary-IND-Chennai-ADM6.geojson
# data/boundaries/v_0/raw/boundary-IND-Chennai-ADM6union.geojson
# data/boundaries/v_0/raw/boundary-IND-Pune-ADM4.geojson
# data/boundaries/v_0/raw/boundary-IND-Pune-ADM4union.geojson
# data/boundaries/v_0/raw/boundary-IND-Surat-ADM4.geojson
# data/boundaries/v_0/raw/boundary-IND-Surat-ADM4union.geojson
# data/boundaries/v_0/raw/boundary-MAR-Marrakech-ADM2.geojson
# data/boundaries/v_0/raw/boundary-MAR-Marrakech-ADM5.geojson
# data/boundaries/v_0/raw/boundary-RWA-Kigali-ADM4.geojson
# data/boundaries/v_0/raw/boundary-RWA-Kigali-ADM4union.geojson
# data/boundaries/v_0/raw/boundary-SLE-Freetown-ADM4city.geojson
# data/boundaries/v_0/raw/boundary-SLE-Freetown-ADM4cityunion.geojson
# data/boundaries/v_0/raw/boundary-SLE-Freetown-ADM4region.geojson
# data/boundaries/v_0/raw/boundary-SLE-Freetown-ADM4regionunion.geojson
# data/emission/
# data/land_use/
# data/land_use/GAIA/
# data/land_use/GAIA/CRI-San_Jose-GAIA_impervious_surfaces.tif
# data/land_use/GLAD-ARD/
# data/land_use/GLAD-ARD/ARG-Buenos_Aires-GLAD-2000.tif
# data/land_use/GLAD-ARD/ARG-Buenos_Aires-GLAD-2020.tif
# data/land_use/GLAD-ARD/ARG-Mar_del_Plata-GLAD-2000.tif
# data/land_use/GLAD-ARD/ARG-Mar_del_Plata-GLAD-2020.tif
# data/land_use/GLAD-ARD/ARG-Mendoza-GLAD-2000.tif
# data/land_use/GLAD-ARD/ARG-Mendoza-GLAD-2020.tif
# data/land_use/GLAD-ARD/ARG-Salta-GLAD-2000.tif
# data/land_use/GLAD-ARD/ARG-Salta-GLAD-2020.tif
# data/land_use/GLAD-ARD/ARG-Ushuaia-GLAD-2000.tif
# data/land_use/GLAD-ARD/ARG-Ushuaia-GLAD-2020.tif
# data/land_use/GLAD-ARD/BRA-Belem-GLAD-2000.tif
# data/land_use/GLAD-ARD/BRA-Belem-GLAD-2020.tif
# data/land_use/GLAD-ARD/BRA-Florianopolois-GLAD-2000.tif
# data/land_use/GLAD-ARD/BRA-Florianopolois-GLAD-2020.tif
# data/land_use/GLAD-ARD/BRA-Teresina-GLAD-2000.tif
# data/land_use/GLAD-ARD/BRA-Teresina-GLAD-2020.tif
# data/land_use/GLAD-ARD/CHN-Chengdu-GLAD-2000.tif
# data/land_use/GLAD-ARD/CHN-Chengdu-GLAD-2020.tif
# data/land_use/GLAD-ARD/CHN-Chongqing-GLAD-2000.tif
# data/land_use/GLAD-ARD/CHN-Chongqing-GLAD-2020.tif
# data/land_use/GLAD-ARD/CHN-Ningbo-GLAD-2000.tif
# data/land_use/GLAD-ARD/CHN-Ningbo-GLAD-2020.tif
# data/land_use/GLAD-ARD/CRI-San_Jose-GLAD-2000.tif
# data/land_use/GLAD-ARD/CRI-San_Jose-GLAD-2020.tif
# data/land_use/GLAD-ARD/CRI-San_Jose-GLAD-ARD.tif
# data/land_use/GLAD-ARD/CRI-San_Jose-GLAD_2000.tif
# data/land_use/GLAD-ARD/CRI-San_Jose-GLAD_2020.tif
# data/land_use/GLAD-ARD/IDN-Balikpapan-GLAD-2000.tif
# data/land_use/GLAD-ARD/IDN-Balikpapan-GLAD-2020.tif
# data/land_use/GLAD-ARD/IDN-Bitung-GLAD-2000.tif
# data/land_use/GLAD-ARD/IDN-Bitung-GLAD-2020.tif
# data/land_use/GLAD-ARD/IDN-Jakarta-GLAD-2000.tif
# data/land_use/GLAD-ARD/IDN-Jakarta-GLAD-2020.tif
# data/land_use/GLAD-ARD/IDN-Palembang-GLAD-2000.tif
# data/land_use/GLAD-ARD/IDN-Palembang-GLAD-2020.tif
# data/land_use/GLAD-ARD/IDN-Semarang-GLAD-2000.tif
# data/land_use/GLAD-ARD/IDN-Semarang-GLAD-2020.tif
# data/land_use/GLAD-ARD/IND-Chennai-GLAD-2000.tif
# data/land_use/GLAD-ARD/IND-Chennai-GLAD-2020.tif
# data/land_use/GLAD-ARD/IND-Pune-GLAD-2000.tif
# data/land_use/GLAD-ARD/IND-Pune-GLAD-2020.tif
# data/land_use/GLAD-ARD/IND-Surat-GLAD-2000.tif
# data/land_use/GLAD-ARD/IND-Surat-GLAD-2020.tif
# data/land_use/GLAD-ARD/MAR-Marrakech-GLAD-2000.tif
# data/land_use/GLAD-ARD/MAR-Marrakech-GLAD-2020.tif
# data/land_use/GLAD-ARD/RWA-Kigali-GLAD-2000.tif
# data/land_use/GLAD-ARD/RWA-Kigali-GLAD-2020.tif
# data/land_use/GLAD-ARD/SLE-Freetown_region-GLAD-2000.tif
# data/land_use/GLAD-ARD/SLE-Freetown_region-GLAD-2020.tif
# data/land_use/GLAD-ARD/test.tif
# data/land_use/dynamic_world/
# data/land_use/dynamic_world/CRI-San_Jose-landcover2016.tif
# data/land_use/dynamic_world/CRI-San_Jose-landcover2017.tif
# data/land_use/dynamic_world/CRI-San_Jose-landcover2018.tif
# data/land_use/dynamic_world/CRI-San_Jose-landcover2019.tif
# data/land_use/dynamic_world/CRI-San_Jose-landcover2020.tif
# data/land_use/dynamic_world/RWA-Kigali-landcover2016.tif
# data/land_use/dynamic_world/RWA-Kigali-landcover2017.tif
# data/land_use/dynamic_world/RWA-Kigali-landcover2018.tif
# data/land_use/dynamic_world/RWA-Kigali-landcover2019.tif
# data/land_use/dynamic_world/RWA-Kigali-landcover2020.tif
# data/land_use/dynamic_world/SLE-Freetown_core-landcover2016.tif
# data/land_use/dynamic_world/SLE-Freetown_core-landcover2017.tif
# data/land_use/dynamic_world/SLE-Freetown_core-landcover2018.tif
# data/land_use/dynamic_world/SLE-Freetown_core-landcover2019.tif
# data/land_use/dynamic_world/SLE-Freetown_core-landcover2020.tif
# data/land_use/esa_world_cover/
# data/land_use/esa_world_cover/CRI-San_Jose-ADM2union-ESA-world_cover-2000-opt.tif
# data/land_use/esa_world_cover/v_0/
# data/land_use/esa_world_cover/v_0/ARG-Buenos_Aires-ADM2union-ESA-world_cover-2000-natural_areas.tif
# data/land_use/esa_world_cover/v_0/ARG-Buenos_Aires-ADM2union-ESA-world_cover-2000.tif
# data/land_use/esa_world_cover/v_0/ARG-Mar_del_Plata-ADM2-ESA-world_cover-2000.tif
# data/land_use/esa_world_cover/v_0/ARG-Mar_del_Plata-ADM3-ESA-world_cover-2000-natural_areas.tif
# data/land_use/esa_world_cover/v_0/ARG-Mar_del_Plata-ADM3-ESA-world_cover-2000.tif
# data/land_use/esa_world_cover/v_0/ARG-Mendoza-ADM3union-ESA-world_cover-2000-natural_areas.tif
# data/land_use/esa_world_cover/v_0/ARG-Mendoza-ADM3union-ESA-world_cover-2000.tif
# data/land_use/esa_world_cover/v_0/ARG-Salta-ADM2union-ESA-world_cover-2000-natural_areas.tif
# data/land_use/esa_world_cover/v_0/ARG-Salta-ADM2union-ESA-world_cover-2000.tif
# data/land_use/esa_world_cover/v_0/ARG-Ushuaia-ADM3-ESA-world_cover-2000.tif
# data/land_use/esa_world_cover/v_0/ARG-Ushuaia-ADM4-ESA-world_cover-2000-natural_areas.tif
# data/land_use/esa_world_cover/v_0/ARG-Ushuaia-ADM4-ESA-world_cover-2000.tif
# data/land_use/esa_world_cover/v_0/BRA-Belem-ADM2union-ESA-world_cover-2000.tif
# data/land_use/esa_world_cover/v_0/BRA-Belem-ADM4union-ESA-world_cover-2000-natural_areas.tif
# data/land_use/esa_world_cover/v_0/BRA-Belem-ADM4union-ESA-world_cover-2000.tif
# data/land_use/esa_world_cover/v_0/BRA-Florianopolis-ADM2union-ESA-world_cover-2000.tif
# data/land_use/esa_world_cover/v_0/BRA-Florianopolis-ADM4union-ESA-world_cover-2000-natural_areas.tif
# data/land_use/esa_world_cover/v_0/BRA-Florianopolis-ADM4union-ESA-world_cover-2000.tif
# data/land_use/esa_world_cover/v_0/BRA-Teresina-ADM2union-ESA-world_cover-2000.tif
# data/land_use/esa_world_cover/v_0/BRA-Teresina-ADM4union-ESA-world_cover-2000-natural_areas.tif
# data/land_use/esa_world_cover/v_0/BRA-Teresina-ADM4union-ESA-world_cover-2000.tif
# data/land_use/esa_world_cover/v_0/CHN-Chengdu-ADM3union-ESA-world_cover-2000.tif
# data/land_use/esa_world_cover/v_0/CHN-Chongqing-ADM1-ESA-world_cover-2000.tif
# data/land_use/esa_world_cover/v_0/CHN-Ningbo-ADM3union-ESA-world_cover-2000-natural_areas.tif
# data/land_use/esa_world_cover/v_0/CHN-Ningbo-ADM3union-ESA-world_cover-2000.tif
# data/land_use/esa_world_cover/v_0/CRI-San_Jose-ADM2union-ESA-world_cover-2000-natural_areas.tif
# data/land_use/esa_world_cover/v_0/CRI-San_Jose-ADM2union-ESA-world_cover-2000.tif
# data/land_use/esa_world_cover/v_0/IDN-Balikpapan-ADM4union-ESA-world_cover-2000-natural_areas.tif
# data/land_use/esa_world_cover/v_0/IDN-Balikpapan-ADM4union-ESA-world_cover-2000.tif
# data/land_use/esa_world_cover/v_0/IDN-Bitung-ADM2-ESA-world_cover-2000-natural_areas.tif
# data/land_use/esa_world_cover/v_0/IDN-Bitung-ADM2-ESA-world_cover-2000.tif
# data/land_use/esa_world_cover/v_0/IDN-Jakarta-ADM4union-ESA-world_cover-2000-natural_areas.tif
# data/land_use/esa_world_cover/v_0/IDN-Jakarta-ADM4union-ESA-world_cover-2000.tif
# data/land_use/esa_world_cover/v_0/IDN-Palembang-ADM2-ESA-world_cover-2000-natural_areas.tif
# data/land_use/esa_world_cover/v_0/IDN-Palembang-ADM2-ESA-world_cover-2000.tif
# data/land_use/esa_world_cover/v_0/IDN-Semarang-ADM1-ESA-world_cover-2000-natural_areas.tif
# data/land_use/esa_world_cover/v_0/IDN-Semarang-ADM1-ESA-world_cover-2000.tif
# data/land_use/esa_world_cover/v_0/IND-Chennai-ADM4union-ESA-world_cover-2000-natural_areas.tif
# data/land_use/esa_world_cover/v_0/IND-Chennai-ADM4union-ESA-world_cover-2000.tif
# data/land_use/esa_world_cover/v_0/IND-Chennai-ADM6union-ESA-world_cover-2000.tif
# data/land_use/esa_world_cover/v_0/IND-Pune-ADM4union-ESA-world_cover-2000-natural_areas.tif
# data/land_use/esa_world_cover/v_0/IND-Pune-ADM4union-ESA-world_cover-2000.tif
# data/land_use/esa_world_cover/v_0/IND-Surat-ADM4union-ESA-world_cover-2000-natural_areas.tif
# data/land_use/esa_world_cover/v_0/IND-Surat-ADM4union-ESA-world_cover-2000.tif
# data/land_use/esa_world_cover/v_0/MAR-Marrakech-ADM2-ESA-world_cover-2000-natural_areas.tif
# data/land_use/esa_world_cover/v_0/MAR-Marrakech-ADM2-ESA-world_cover-2000.tif
# data/land_use/esa_world_cover/v_0/RWA-Kigali-ADM4union-ESA-world_cover-2000.tif
# data/land_use/esa_world_cover/v_0/SLE-Freetown-ADM4cityunion-ESA-world_cover-2000-natural_areas.tif
# data/land_use/esa_world_cover/v_0/SLE-Freetown-ADM4cityunion-ESA-world_cover-2000.tif
# data/land_use/esa_world_cover/v_0/SLE-Freetown-ADM4regionunion-ESA-world_cover-2000.tif
# data/land_use/esa_world_cover/v_0/metadata.json
# data/land_use/esa_world_cover/world_cover_10m_CRI-San_Jose.tif
# data/land_use/esa_world_cover/world_cover_ARG-Buenos_Aires.tif
# data/land_use/esa_world_cover/world_cover_ARG-Mar_del_Plata.tif
# data/land_use/esa_world_cover/world_cover_ARG-Mendoza.tif
# data/land_use/esa_world_cover/world_cover_ARG-Salta.tif
# data/land_use/esa_world_cover/world_cover_ARG-Ushuaia.tif
# data/land_use/esa_world_cover/world_cover_BRA-Belem.tif
# data/land_use/esa_world_cover/world_cover_BRA-Florianopolois.tif
# data/land_use/esa_world_cover/world_cover_BRA-Teresina.tif
# data/land_use/esa_world_cover/world_cover_CHN-Chengdu.tif
# data/land_use/esa_world_cover/world_cover_CHN-Chongqing.tif
# data/land_use/esa_world_cover/world_cover_CHN-Ningbo.tif
# data/land_use/esa_world_cover/world_cover_CRI-San_Jose.tif
# data/land_use/esa_world_cover/world_cover_IDN-Balikpapan.tif
# data/land_use/esa_world_cover/world_cover_IDN-Bitung.tif
# data/land_use/esa_world_cover/world_cover_IDN-Jakarta.tif
# data/land_use/esa_world_cover/world_cover_IDN-Palembang.tif
# data/land_use/esa_world_cover/world_cover_IDN-Semarang.tif
# data/land_use/esa_world_cover/world_cover_IND-Chennai.tif
# data/land_use/esa_world_cover/world_cover_IND-Pune.tif
# data/land_use/esa_world_cover/world_cover_IND-Surat.tif
# data/land_use/esa_world_cover/world_cover_MAR-Marrakech.tif
# data/land_use/esa_world_cover/world_cover_RWA-Kigali.tif
# data/land_use/esa_world_cover/world_cover_SLE-Freetown_region.tif
# data/land_use/sentinel2_ndvi/
# data/land_use/sentinel2_ndvi/CRI-San_Jose-maxNDVI2016.tif
# data/land_use/sentinel2_ndvi/CRI-San_Jose-maxNDVI2017.tif
# data/land_use/sentinel2_ndvi/CRI-San_Jose-maxNDVI2018.tif
# data/land_use/sentinel2_ndvi/CRI-San_Jose-maxNDVI2019.tif
# data/land_use/sentinel2_ndvi/CRI-San_Jose-maxNDVI2020.tif
# data/land_use/sentinel2_ndvi/RWA-Kigali-maxNDVI2016.tif
# data/land_use/sentinel2_ndvi/RWA-Kigali-maxNDVI2017.tif
# data/land_use/sentinel2_ndvi/RWA-Kigali-maxNDVI2018.tif
# data/land_use/sentinel2_ndvi/RWA-Kigali-maxNDVI2019.tif
# data/land_use/sentinel2_ndvi/RWA-Kigali-maxNDVI2020.tif
# data/land_use/sentinel2_ndvi/SLE-Freetown_core-maxNDVI2016.tif
# data/land_use/sentinel2_ndvi/SLE-Freetown_core-maxNDVI2017.tif
# data/land_use/sentinel2_ndvi/SLE-Freetown_core-maxNDVI2018.tif
# data/land_use/sentinel2_ndvi/SLE-Freetown_core-maxNDVI2019.tif
# data/land_use/sentinel2_ndvi/SLE-Freetown_core-maxNDVI2020.tif
# data/land_use/trees_outside_forest/
# data/land_use/trees_outside_forest/CRI-San_Jose-treecover2020.tif
# data/land_use/trees_outside_forest/RWA-Kigali-treecover2020.tif
# data/land_use/trees_outside_forest/SLE-Freetown_core-treecover2020.tif
# data/land_use/urban_land_use/
# data/land_use/urban_land_use/CRI-San_Jose-urbanlanduse2020.tif
# data/land_use/urban_land_use/RWA-Kigali-urbanlanduse2020.tif
# data/land_use/urban_land_use/SLE-Freetown_core-urbanlanduse2020.tif
# data/natural_hazards/
# data/population/
# data/population/CRI-San_Jose_pop.tif
# data/tree_cover/
# data/tree_cover/tree_mosaic_land/
# data/tree_cover/tree_mosaic_land/v_0/
# data/tree_cover/tree_mosaic_land/v_0/BRA-Belem-ADM2union-TML-tree_cover-2000.tif
# data/tree_cover/tree_mosaic_land/v_0/BRA-Belem-ADM4union-TML-tree_cover-2000.tif
# data/tree_cover/tree_mosaic_land/v_0/BRA-Teresina-ADM2union-TML-tree_cover-2000.tif
# data/tree_cover/tree_mosaic_land/v_0/BRA-Teresina-ADM4union-TML-tree_cover-2000.tif
# data/tree_cover/tree_mosaic_land/v_0/CRI-San_Jose-ADM2union-TML-tree_cover-2000.tif
# data/tree_cover/tree_mosaic_land/v_0/IDN-Balikpapan-ADM4union-TML-tree_cover-2000.tif
# data/tree_cover/tree_mosaic_land/v_0/IDN-Bitung-ADM2-TML-tree_cover-2000.tif
# data/tree_cover/tree_mosaic_land/v_0/IDN-Jakarta-ADM4union-TML-tree_cover-2000.tif
# data/tree_cover/tree_mosaic_land/v_0/IDN-Semarang-ADM1-TML-tree_cover-2000.tif
# data/tree_cover/tree_mosaic_land/v_0/IND-Chennai-ADM4union-TML-tree_cover-2000.tif
# data/tree_cover/tree_mosaic_land/v_0/IND-Surat-ADM4union-TML-tree_cover-2000.tif
# data/tree_cover/tree_mosaic_land/v_0/MAR-Marrakech-ADM2-TML-tree_cover-2000.tif
# data/tree_cover/tree_mosaic_land/v_0/RWA-Kigali-ADM4union-TML-tree_cover-2000.tif
# data/tree_cover/tree_mosaic_land/v_0/SLE-Freetown-ADM4cityunion-TML-tree_cover-2000.tif
# data/tree_cover/tree_mosaic_land/v_0/SLE-Freetown-ADM4regionunion-TML-tree_cover-2000.tif
# data/tree_cover/tree_mosaic_land/v_0/metadata.json
# data/urbanshift_metadata.json
# indicators/
# indicators/biodiversity/BIO-3.csv
# indicators/cities_indicators.csv
# indicators/cities_indicators_erictest.csv
# indicators/cities_indicators_v2.csv
# indicators/cities_indicators_v2_test-ted.csv
# indicators/cities_lulc_stats.csv
# indicators/indicators_definition.csv
# maps/
# maps/Barranquilla_map.html
# maps/DireDawa_map.html
# maps/Fig-2.html
# maps/Fig-3.html
# maps/Fig-4.html
# maps/blog-post-map-test.html
# reports/
# reports/UrbanShift-Biodiversity-ARG-Buenos_Aires-Layers.html
# reports/UrbanShift-Biodiversity-ARG-Buenos_Aires.html
# reports/UrbanShift-Biodiversity-ARG-Mendoza-Layers.html
# reports/UrbanShift-Biodiversity-ARG-Mendoza.html
# reports/UrbanShift-Biodiversity-ARG-Salta-Layers.html
# reports/UrbanShift-Biodiversity-ARG-Salta.html
# reports/UrbanShift-Biodiversity-ARG-Ushuaia-Layers.html
# reports/UrbanShift-Biodiversity-ARG-Ushuaia.html
# reports/UrbanShift-Biodiversity-BRA-Belem-Layers.html
# reports/UrbanShift-Biodiversity-BRA-Belem.html
# reports/UrbanShift-Biodiversity-BRA-Florianopolois-Layers.html
# reports/UrbanShift-Biodiversity-BRA-Florianopolois.html
# reports/UrbanShift-Biodiversity-BRA-Teresina-Layers.html
# reports/UrbanShift-Biodiversity-BRA-Teresina.html
# reports/UrbanShift-Biodiversity-CHN-Chengdu.html
# reports/UrbanShift-Biodiversity-CHN-Chongqing.html
# reports/UrbanShift-Biodiversity-CHN-Ningbo.html
# reports/UrbanShift-Biodiversity-CRI-San_Jose-Layers.html
# reports/UrbanShift-Biodiversity-CRI-San_Jose.html
# reports/UrbanShift-Biodiversity-IDN-Balikpapan.html
# reports/UrbanShift-Biodiversity-IDN-Bitung.html
# reports/UrbanShift-Biodiversity-IDN-Jakarta.html
# reports/UrbanShift-Biodiversity-IDN-Palembang.html
# reports/UrbanShift-Biodiversity-IDN-Semarang.html
# reports/UrbanShift-Biodiversity-IND-Chennai.html
# reports/UrbanShift-Biodiversity-IND-Pune.html
# reports/UrbanShift-Biodiversity-IND-Surat.html
# reports/UrbanShift-Biodiversity-MAR-Marrakech.html
# reports/UrbanShift-Biodiversity-RWA-Kigali.html
# reports/UrbanShift-Biodiversity-SLE-Freetown.html
# thematic-analysis/
# thematic-analysis/freetown/
# thematic-analysis/freetown/Freetown-thematic-analysis.html
# thematic-analysis/freetown/data/
# thematic-analysis/freetown/data/SLE-Freetown_core-boundary.geojson
# thematic-analysis/freetown/data/freetown_landuse_projected.geojson
# thematic-analysis/freetown/data/freetown_municipality_boundary.geojson
# thematic-analysis/freetown/data/freetown_municipality_land_use.geojson
# thematic-analysis/freetown/data/freetown_planning_area.geojson
# thematic-analysis/freetown/data/freetown_wards.geojson
# thematic-analysis/freetown/maps/
# thematic-analysis/freetown/maps/land-classification-2016.png
# thematic-analysis/freetown/maps/land-classification-2021.png
# thematic-analysis/freetown/maps/land-use-map.png
# thematic-analysis/freetown/maps/urban-expansion-2016-2021-by-land-use-classes.png
# thematic-analysis/freetown/maps/urban-expansion-2016-2021-planning-areas.png
# thematic-analysis/freetown/maps/urban-expansion-2016-2021-wards.png
# thematic-analysis/freetown/maps/urban-expansion-2016-2021.png
# thematic-analysis/freetown/reports/
# thematic-analysis/freetown/reports/Freetown-thematic-analysis.html
